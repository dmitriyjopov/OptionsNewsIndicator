# %%
import pandas as pd
import numpy as np

# %%
news_df = pd.read_csv('сбербанк_3day_news.csv')
news_df['date'] = pd.to_datetime(news_df['date'])

# %%
news_df['date_column_cleaned'] = pd.to_datetime(news_df['scraped_date'], errors='coerce')

# Теперь удаляем строки, где преобразование не удалось
news_df = news_df.dropna(subset=['date_column_cleaned'])

# %%
news_df.head(30)

# %% [markdown]
# ## Форматирование scraped даты

# %%
months = {
    'январь': '01',
    'февраль': '02'
}

def process_date(date):
    possible_month = date.split()[0]
    for month in months.keys():
        if month in date:
            numerical_month = months.get(month)
            formatted_date = '-'.join(date.split()[0], numerical_month, date.split()[-1])
            return formatted_date

# %% [markdown]
# ## Модель Facebook для классификации

# %%
import torch
from transformers import pipeline

device = 0 if torch.cuda.is_available() else -1
print('Видюха поддерживается!') if device == 0 else print('Видюха НЕ поддерживается :(')
classifier = pipeline(
    "zero-shot-classification", 
    model="facebook/bart-large-mnli", 
    device=device
)

# %%
classified_dataset = 'sberbank_2d_facebook_model_class.csv'

# %% [markdown]
# #### Классификация summary текста

# %%
candidate_labels = ["Financials & Dividends", "Strategy & Corporate Events", "Market Analysis & Expert Forecasts", "Macro & Regulation",  "Retail Products & Marketing", "Service & Tech Updates"]

def process_news_batched(df, batch_size=8):
    df = df.copy()
    texts = df['summary'].tolist()
    
    all_results = []

    for i in range(0, len(texts), batch_size):
        batch_texts = texts[i:i + batch_size]
        
        batch_results = classifier(
            batch_texts, 
            candidate_labels, 
            multi_label=False
        )
        
        if isinstance(batch_results, dict):
            batch_results = [batch_results]
            
        all_results.extend(batch_results)
        print(f"Обработано {min(i + batch_size, len(texts))}/{len(texts)}")

    for label in candidate_labels:
        df[label] = [
            res['scores'][res['labels'].index(label)] 
            for res in all_results
        ]
        
    return df

news_df = process_news_batched(news_df, batch_size=8) # Начните с 4 для 1060
news_df.to_csv(classified_dataset)

# %%
def extract_publisher(title):
    return title.split(' - ')[-1]

unique_pubs = news_df['title'].apply(extract_publisher)
print(f'уникальные издания: {np.unique(unique_pubs)}')

# %% [markdown]
# ## Расчет Market Index

# %%
''' словарь с весами изданий '''
source_weights = {
    # --- TIER 1: Максимальное влияние (Институционалы, Биржи, ГосСМИ) ---
    'Интерфакс': 2.0,
    'Интерфакс Россия': 1.8,
    'Московская Биржа': 2.0,
    'Ведомости': 1.8,
    'Forbes.ru': 1.7,
    'Сбербанк': 1.7,
    'PJSC Sberbank': 1.7,
    'ОАО «Сбер Банк': 1.5,
    'Альфа-Банк': 1.5,
    'БКС Экспресс': 1.5,
    'Финам.Ру': 1.5,
    'Коммерсантъ': 1.8, # (Если появится в списке)
    'ПРАВО.Ru': 1.4,
    'РАПСИ': 1.3,

    # --- TIER 2: Профильные финансы, Технологии и Рынки ---
    'Investing.com': 1.3,
    'Smart-Lab': 1.3,
    'ProFinance': 1.3,
    'Банки.ру': 1.2,
    'Эксперт': 1.2,
    'Frank Media': 1.2,
    'InvestFuture': 1.1,
    'Finmarket.ru': 1.1,
    'CNews.ru': 1.1,
    'Хабр': 1.1,
    'iXBT.com': 1.0,
    '3DNews': 1.0,
    'CoinDesk': 1.0,
    'Zakon.ru': 1.0,
    'BFM.ru': 1.1,
    'Клерк.ру': 1.0,

    # --- TIER 3: Крупные агрегаторы и Федеральные СМИ ---
    'ФОНТАНКА.ру': 1.0,
    'URA.RU': 1.0,
    'NEWS.ru': 0.9,
    'Lenta.ru': 0.9, # (Если появится)
    'Т—Ж': 0.9,
    't-j.ru': 0.9,
    'Лайфхакер': 0.8,
    'Аргументы и Факты': 0.8,
    'БИЗНЕС Online — Новости Казани': 0.9,
    'Независимая газета': 0.9,
    'ФедералПресс': 0.8,
    'SIA.RU': 0.8,
    'Сибирское информационное агентство': 0.8,

    # --- TIER 4: Заметные региональные и отраслевые СМИ ---
    'НГС.ру': 0.7,
    '74.ру': 0.7,
    '59.ру': 0.7,
    'NGS.42': 0.7,
    'Алтапресс — новости Барнаула и Алтайского края': 0.6,
    'PrimaMedia': 0.6,
    'SakhalinMedia': 0.6,
    'ЯСИА': 0.6,
    'Сибкрай.ru': 0.6,
    'Vremyan.ru': 0.5,
    'Время Н': 0.5,
    'Выберу.ру': 0.5,
    'ВсеЗаймыОнлайн': 0.4,
    'ADIndex.ru': 0.5,
    'Sostav.ru': 0.5,
    'AppleInsider.ru': 0.5,

    # --- TIER 5: Мелкие региональные порталы и шум ---
    # Для всех остальных устанавливаем базовый низкий вес
}

# %%
indicator_pipe = pipeline(task='text-classification', model='ProsusAI/finbert')

# %%
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.lex_rank import LexRankSummarizer
from nltk.tokenize import sent_tokenize
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')

def get_summary(text, max_sentences):
    if not text or len(text) < 100: return "Текст слишком короткий"
    
    # 1. ПРЕДВАРИТЕЛЬНАЯ ЧИСТКА
    # Заменяем переносы строк на пробелы, чтобы склеенные строки разошлись
    clean_text = text.replace("\n", " ").replace("\r", " ")
    
    # Убираем лишние пробелы (два и более подряд)
    clean_text = " ".join(clean_text.split())

    try:
        # 2. Sumy выбирает "лучший кусок" текста
        parser = PlaintextParser.from_string(clean_text, Tokenizer("russian"))
        summarizer = LexRankSummarizer()
        
        # Просим Sumy дать 1 предложение. 
        # Но если токенизатор ошибся, Sumy вернет огромный кусок.
        sumy_result = summarizer(parser.document, max_sentences)
        raw_summary = " ".join([str(s) for s in sumy_result])
        
        # 3. ФИНАЛЬНАЯ НАРЕЗКА (SAFETY NET)
        # Мы берем то, что вернула Sumy, и еще раз режем на предложения через NLTK
        real_sentences = sent_tokenize(raw_summary, language="russian")
        
        if real_sentences:
            # Возвращаем СТРОГО первое предложение
            return ' '.join(real_sentences[:max_sentences])
        else:
            return raw_summary
            
    except Exception as e:
        print(f"Ошибка в NLP: {e}")
        return "Ошибка обработки"

def calculate_sentiment_index(neutral, positive, negative):
    sentiment_index = (positive * 1.0) + (neutral * 0.5) + (negative * 0.0)
    return round(sentiment_index, 4)

def calculate_market_index(summary):
    for length in range(4, 1, -1):
        try:
            print(f'пробуем длину {length}')
            short_summary = get_summary(summary, max_sentences=length)
            result_all = indicator_pipe(short_summary, top_k=None)
            idx = calculate_sentiment_index(result_all[0]['score'], result_all[1]['score'], result_all[2]['score'])
            return idx
        except Exception as e:
            if hasattr(str(e), 'Token indices sequence length') or hasattr(str(e), 'The size of tensor'):
                print('ошибка длины, сжимаем...')
                continue

# %%
index_dateset = 'sberbank_2d_facebook_model_class_with_index.csv'

# %%
df_index = pd.read_csv(classified_dataset)
df_index['news_index'] = df_index[df_index["Retail Products & Marketing"] + df_index["Service & Tech Updates"] < 0.3]['summary'].apply(calculate_market_index)

df_index.to_csv(index_dateset)

# %% [markdown]
# #### взвешенный индекс

# %%
def weight_index(index, publisher):
    if index is not None:
        coeff = source_weights.get(publisher, 1)
        return index * coeff
    return None

for idx, row in df_index.iterrows():
    publisher = (row['title']).split(' - ')[-1]
    df_index.at[idx, 'news_index'] = weight_index(
        index=row['news_index'], 
        publisher=publisher
    )

# %%
df_index['scraped_date'] = pd.to_datetime(df_index['scraped_date'], format='mixed', utc=True)
df_index.set_index(df_index['scraped_date'], inplace=True)
# df_index = df_index.drop(columns=['Unnamed: 0', 'scraped_date'])
df_index = df_index.drop(columns=['scraped_date'])

# %%
print(df_index.columns)
df_index = df_index.drop(columns=['Unnamed: 0'])
df_index

# %% [markdown]
# ## Эмбеддинг и кластеризация summary статей
# ### Модель - **intfloat/multilingual-e5-large**

# %%
df_index = pd.read_csv(index_dateset) # c посчитанным индексом

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('intfloat/multilingual-e5-large')

# %%
input_texts = [f"query: {text}" for text in df_index['summary']]
embeddings = model.encode(input_texts, normalize_embeddings=True)
print(f'embeddings:\n{embeddings[:10]} ...')

# %%
df_index['vector'] = [embeddings[i] for i in range(len(embeddings))]
np.save('embeddings.npy', embeddings)

# %% [markdown]
# ### Кластеризация эмбеддингов

# %%
index_dateset = 'sberbank_2d_facebook_model_class_with_index.csv'

# %%
import numpy as np
import pandas as pd

df_index = pd.read_csv(index_dateset)
embeddings = np.load('embeddings.npy')

df_index['scraped_date'] = pd.to_datetime(df_index['scraped_date'], format='mixed', utc=True)
# df_index.set_index(df_index['scraped_date'], inplace=True)
df_index = df_index.drop(columns=['Unnamed: 0', 'Unnamed: 0.1'])

# df_index = df_index.drop(columns=['scraped_date'])

# %%
df_index
# Out:
#                      date              scraped_date  \
# 0     2025-12-01 08:00:00 2025-12-01 13:56:00+00:00
# 1     2025-12-01 08:00:00 2025-12-01 13:08:00+00:00
# 2     2025-12-04 08:00:00 2025-12-04 18:17:00+00:00
# 3     2025-12-01 08:00:00 2025-12-01 13:45:00+00:00
# 4     2025-12-01 08:00:00 2025-12-01 17:49:00+00:00
# ...                   ...                       ...
# 1299  2026-02-24 08:00:00 2026-02-24 19:09:00+00:00
# 1300  2026-02-25 13:00:59 2026-02-25 13:00:00+00:00
# 1301  2026-02-25 10:35:59 2026-02-25 13:35:00+00:00
# 1302  2026-02-26 08:00:00 2026-02-26 16:53:00+00:00
# 1303  2026-02-25 14:54:24 2026-02-25 13:18:00+00:00
#
#                                                   title  \
# 0     Сбербанк запустил оплату по QR-коду в Китае - ...
# 1     В Сбербанке заявили, что более 6 тыс. компаний...
# 2     Сбербанк и ВТБ рассказали о планах развивать р...
# 3     Сбербанк: расчеты между РФ и Индией в нацвалют...
# 4     Сбербанк и ИТМО открыли коворкинг в историческ...
# ...                                                 ...
# 1299  Стоит ли открывать шорт по Сбербанку на текущи...
# 1300  Розничный кредитный портфель Сбербанка в Марий...
# 1301      Сбербанк снижает ставки по ипотеке - Zaim.com
# 1302  Греф дал прогноз по курсу доллара и назвал клю...
# 1303  Сбербанк сократил ставку по рыночной ипотеке д...
#
#                                                     url  \
# 0     https://expert.ru/news/sberbank-zapustil-oplat...
# 1             https://www.alta.ru/external_news/123771/
# 2     https://www.forbes.ru/finansy/551333-sberbank-...
# 3     https://finance.mail.ru/article/sberbank-rasch...
# 4     https://www.cnews.ru/news/line/2025-12-01_sber...
# ...                                                 ...
# 1299  https://news.mondiara.com/categories/18/posts/...
# 1300  https://potokmedia.ru/726126/roznichnyj-kredit...
# 1301  https://zaim.com/news/sberbank-snizhaet-stavki...
# 1302       https://www.fontanka.ru/2026/02/26/76284048/
# 1303  https://rznonline.ru/news/society/item/sberban...
#
#                                                 summary  date_column_cleaned  \
# 0     Курс конвертации отображается заранее. Один из...  2025-12-01 13:56:00
# 1     Более 6 тыс. индийских компаний заинтересованы...  2025-12-01 13:08:00
# 2     По его словам, банк ждет одобрения регулятора ...  2025-12-04 18:17:00
# 3     «Большая часть расчетов между Россией и Индией...  2025-12-01 13:45:00
# 4     Сбербанк и ИТМО открыли коворкинг в историческ...  2025-12-01 17:49:00
# ...                                                 ...                  ...
# 1299  СБЕРБАНК [анализ] [SBER] АНАЛИЗ АКЦИЙ РОССИИ С...  2026-02-24 19:09:00
# 1300  Портфель жилищных кредитов в Сбере вырос на 24...  2026-02-25 13:00:00
# 1301  С 26 февраля Сбер смягчает условия по базовым ...  2026-02-25 13:35:00
# 1302  Председатель правления Сбербанка Герман Греф д...  2026-02-26 16:53:00
# 1303  Сбербанк объявил о снижении ставок по рыночной...  2026-02-25 13:18:00
#
#       Financials & Dividends  Strategy & Corporate Events  \
# 0                   0.130606                     0.175752
# 1                   0.135380                     0.170500
# 2                   0.115787                     0.185119
# 3                   0.114892                     0.158577
# 4                   0.140714                     0.159085
# ...                      ...                          ...
# 1299                0.166520                     0.166248
# 1300                0.122723                     0.187904
# 1301                0.135873                     0.139189
# 1302                0.157583                     0.178149
# 1303                0.125435                     0.168364
#
#       Market Analysis & Expert Forecasts  Macro & Regulation  \
# 0                               0.196811            0.203383
# 1                               0.202823            0.202666
# 2                               0.192532            0.213854
# 3                               0.197901            0.212726
# 4                               0.164817            0.241957
# ...                                  ...                 ...
# 1299                            0.216415            0.226594
# 1300                            0.192907            0.206225
# 1301                            0.216225            0.228763
# 1302                            0.194156            0.203276
# 1303                            0.172147            0.242958
#
#       Retail Products & Marketing  Service & Tech Updates  news_index
# 0                        0.113176                0.180273      0.5803
# 1                        0.093650                0.194980      0.5576
# 2                        0.106043                0.186663      0.5678
# 3                        0.086506                0.229398         NaN
# 4                        0.101167                0.192260      0.6076
# ...                           ...                     ...         ...
# 1299                     0.065674                0.158549      0.5637
# 1300                     0.096391                0.193849      0.5622
# 1301                     0.090029                0.189922      0.5370
# 1302                     0.092517                0.174320      0.5847
# 1303                     0.094904                0.196192      0.5709
#
# [1304 rows x 13 columns]

# %%
df_index['vector'] = list(embeddings)

# %%
import umap
import hdbscan

reducer = umap.UMAP(
    n_components=3, 
    n_neighbors=5, 
    metric='cosine', 
    random_state=42
)

embedding = reducer.fit_transform(df_index['vector'].values.tolist())
df_index['x'] = embedding[:, 0]
df_index['y'] = embedding[:, 1]
df_index['z'] = embedding[:, 2]

df_index['un_date'] = pd.to_datetime(df_index['scraped_date']).dt.date
for idx, group in df_index.groupby('un_date'):
    if len(group) < 5:
        continue
    vectors = np.stack(group[['x','y','z']].values)
    clusterer = hdbscan.HDBSCAN(
        min_cluster_size=5,
        allow_single_cluster=True,
        cluster_selection_method='eom',
        metric='euclidean'
    )
    labels = clusterer.fit_predict(vectors)

    df_index.loc[group.index, 'cluster_id'] = labels
# Out:
# /Users/a11111/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
df_index[['cluster_id', 'un_date']].head(50)
# Out:
#     cluster_id     un_date
# 0           19  2025-12-01
# 1           -1  2025-12-01
# 2           53  2025-12-04
# 3           -1  2025-12-01
# 4           62  2025-12-01
# 5           74  2025-12-02
# 6           53  2025-12-04
# 7           19  2025-12-01
# 8           19  2025-12-01
# 9           27  2025-12-02
# 10          25  2025-12-02
# 11          79  2025-12-04
# 12          -1  2025-12-04
# 13          25  2025-12-03
# 14          79  2025-12-04
# 15          19  2025-12-02
# 16          -1  2025-12-03
# 17          27  2025-12-02
# 18          34  2025-12-01
# 19          27  2025-12-02
# 20          27  2025-12-02
# 21          58  2025-12-02
# 22          62  2025-12-04
# 23          19  2025-12-01
# 24          27  2025-12-02
# 25          14  2025-12-03
# 26          74  2025-12-01
# 27          19  2025-12-01
# 28          27  2025-12-02
# 29           4  2025-12-02
# 30          20  2025-12-03
# 31          19  2025-12-01
# 32          49  2025-12-01
# 33          17  2025-12-03
# 34          74  2025-12-01
# 35          59  2025-12-02
# 36          62  2025-12-03
# 37          14  2025-12-03
# 38          19  2025-12-04
# 39          51  2025-12-02
# 40          -1  2025-12-04
# 41          -1  2025-12-03
# 42           4  2025-12-01
# 43          51  2025-12-03
# 44          29  2025-12-01
# 45           4  2025-12-01
# 46          -1  2025-12-01
# 47          34  2025-12-01
# 48          71  2025-12-04
# 49          34  2025-12-01

# %%
import plotly.express as px
import pandas as pd
from datetime import timedelta

# 1. Считаем UMAP (как и раньше)
# Рекомендую увеличить n_neighbors для более "глобальной" структуры


# 2. Кластеризация через HDBSCAN
# min_cluster_size — минимальное кол-во новостей, чтобы они считались темой
clusterer = hdbscan.HDBSCAN(
    min_cluster_size=5, 
    metric='euclidean', 
    cluster_selection_method='eom'
)
cluster_labels = clusterer.fit_predict(embedding)

# 3. Собираем данные в DataFrame

df_index['cluster'] = cluster_labels.astype(str)

# %%
df_index['cluster_id'] = cluster_labels

def get_min_date(group):
    return min(group['scraped_date'])

# df_index['min_time'] = df_index.groupby(['un_date']).transform(lambda x: print(x))
# df_index['min_time'] = df_index.groupby(['un_date']).transform(lambda x: x['scraped_date'].min())
df_index['min_time'] = df_index.groupby('un_date')['scraped_date'].transform('min')
df_index['min_time'] = pd.to_datetime(df_index['min_time'])
print(df_index.groupby('un_date')['min_time'])
# Out:
# 0      2025-12-01 01:20:00+00:00
# 1      2025-12-01 01:20:00+00:00
# 2      2025-12-04 07:56:00+00:00
# 3      2025-12-01 01:20:00+00:00
# 4      2025-12-01 01:20:00+00:00
#                   ...
# 1299   2026-02-24 07:59:00+00:00
# 1300   2026-02-25 06:42:00+00:00
# 1301   2026-02-25 06:42:00+00:00
# 1302   2026-02-26 00:20:00+00:00
# 1303   2026-02-25 06:42:00+00:00
# Name: min_time, Length: 1303, dtype: datetime64[us, UTC]

# %% [markdown]
# ### Отрисовка кластеризации

# %%
import textwrap

# Функция для красивого разбиения текста
def format_hover_text(text, width=70):
    if not text:
        return ""
    # Разбиваем текст на строки по ширине (например, 70 символов)
    wrapped = textwrap.fill(str(text), width=width)
    # Заменяем обычный перенос строки на HTML-тег <br>
    return wrapped.replace('\n', '<br>')

# Применяем форматирование
df_index['formatted_summary'] = df_index['summary'].apply(lambda x: format_hover_text(x, width=80))

df_index['hoover_date'] = df_index['scraped_date'].strftime('%Y-%m-%d %H:%M:%S')

# 1. Приводим к строке, чтобы Plotly воспринимал кластеры как категории
df_index['cluster'] = df_index['cluster'].astype(str)

fig = px.scatter_3d(
    df_index, 
    x='x', y='y', z='z',
    color='cluster',
    color_discrete_map={'-1': '#d3d3d3'},
    hover_data={'formatted_summary': True, 'x': False, 'y': False, 'z': False, 'cluster': True, 'hoover_date': True},
    title='Автоматическая кластеризация новостей (HDBSCAN)',
    template='plotly_white',
    width=2700, height=1000
)

# Важная настройка: заставляем подсказку не ограничивать ширину и выравниваем текст
fig.update_layout(
    hoverlabel=dict(
        bgcolor="white",
        font_size=12,
        align="left" # Текст будет прижат к левому краю внутри окна
    )
)

fig.update_traces(marker=dict(size=5, opacity=0.7))
fig.show(renderer="browser")  # сразу откроет в браузере на весь экран
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/9g/ksvcj0yd2b714fy6c81b26v00000gn/T/ipykernel_49628/3325832497.py in ?()
#      11
#      12 # Применяем форматирование
#      13 df_index['formatted_summary'] = df_index['summary'].apply(lambda x: format_hover_text(x, width=80))
#      14
# ---> 15 df_index['hoover_date'] = df_index['scraped_date'].strftime('%Y-%m-%d %H:%M:%S')
#      16
#      17 # 1. Приводим к строке, чтобы Plotly воспринимал кластеры как категории
#      18 df_index['cluster'] = df_index['cluster'].astype(str)
#
# ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'strftime'

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import textwrap

def format_hover_text(text, width=70):
    if not text:
        return ""
    wrapped = textwrap.fill(str(text), width=width)
    return wrapped.replace('\n', '<br>')

df_index['hoover_date'] = pd.to_datetime(df_index['scraped_date'].values).strftime('%Y-%m-%d %H:%M:%S')
df_index['formatted_summary'] = df_index['summary'].apply(lambda x: format_hover_text(x, width=80))

# Создаем фигуру с слайдером
fig = go.Figure()

# Получаем уникальные даты
unique_dates = sorted(df_index['un_date'].unique())

# Добавляем след для каждой даты
for date in unique_dates:
    group = df_index[df_index['un_date'] == date]
    customdata = group[['formatted_summary', 'hoover_date', 'title']].values
    
    fig.add_trace(
        go.Scatter3d(
            x=group['x'],
            y=group['y'],
            z=group['z'],
            mode='markers',
            marker=dict(
                size=5,
                color=group['cluster_id'],
                colorscale='Viridis',
                showscale=True,
                colorbar=dict(title="Cluster ID"),
                opacity=0.8
            ),
            text=group['title'],
            customdata=customdata,
            hovertemplate='<b>%{text}</b><br><br>' +
                         'Summary: %{customdata[0]}<br>' +
                         'Date: %{customdata[1]}<br>' +
                         'Cluster: %{marker.color}<br>' +
                         '<extra></extra>',
            name=f'{date}',
            visible=(date == unique_dates[0])  # Показываем только первую дату
        )
    )

# Создаем шаги для слайдера
steps = []
for i, date in enumerate(unique_dates):
    step = dict(
        method="update",
        args=[{"visible": [False] * len(unique_dates)},
              {"title": f"Date: {date}"}],
        label=str(date)
    )
    step["args"][0]["visible"][i] = True
    steps.append(step)

# Создаем слайдер
sliders = [dict(
    active=0,
    currentvalue={"prefix": "Date: "},
    pad={"t": 50},
    steps=steps
)]

# Обновляем layout
fig.update_layout(
    sliders=sliders,
    height=800,
    width=1200,
    title=f"Date: {unique_dates[0]}",
    hoverlabel=dict(
        bgcolor="white",
        font_size=12,
        font_family="Arial",
        align="left"
    )
)

fig.show(renderer="browser")

# %% [markdown]
# ### График изменения цены сбера против кластеров новостей

# %%
from moexalgo import Ticker, session
from datetime import timedelta
username = "382hejw@gmail.com"
password = "nTpM7b#N*wipF56"
session.authorize(username, password)

# %%
sber = Ticker('SBER')

start_date = df_index.index.min().date()
end_date = df_index.index.max().date()

sber_candles = sber.candles(start=start_date, end=end_date, period='15min')
sber_candles['end'] = pd.to_datetime(sber_candles['end'])
sber_candles.set_index('end', inplace=True)

sber_candles['candle_change'] = sber_candles['close'] - sber_candles['open']
sber_candles['mean'] = sber_candles['candle_change'].rolling(window='1D').mean()
sber_candles['std'] = sber_candles['candle_change'].rolling(window='1D').std()
sber_candles['z-score'] = (sber_candles['candle_change'] - sber_candles['mean']) / sber_candles['std']

# %%
print(df_index)

# %%
import pandas as pd
import plotly.express as px

# 1. Подготовка данных к объединению
# Убеждаемся, что время в обоих DF имеет правильный формат и отсортировано
df_index['min_time'] = pd.to_datetime(df_index['min_time']).dt.tz_localize(None)
sber_candles = sber_candles.sort_values('end')
df_index = df_index.sort_values('min_time')

# 2. Объединение: ищем ближайшую свечу Сбера "впереди" (direction='forward')
# Это сопоставит min_time (13:07) со свечой 13:15
merged_df = pd.merge_asof(
    df_index, 
    sber_candles['z-score'], 
    left_on='min_time', 
    right_on=sber_candles.index, 
    direction='forward'
)

# 3. Убираем шум (аутлайнеры -1), если они не нужны для анализа корреляции
plot_data = merged_df[merged_df['cluster_id'] != '-1'].copy()
plot_data['cluster_id'] = plot_data['cluster_id'].astype(str)

# 4. Построение графика
fig = px.scatter(
    plot_data,
    x='cluster_id',
    y='z-score',
    color='z-score',
    color_continuous_scale='RdBu_r', # Красный для высокого Z, синий для низкого
    hover_data=['min_time', 'summary'],
    title='Влияние кластеров новостей на Z-score SBER',
    labels={'z-score': 'Z-score (15 min)', 'cluster_id': 'ID Кластера'}
)

# Добавим горизонтальные линии для наглядности аномалий
fig.add_hline(y=2, line_dash="dash", line_color="red", annotation_text="Strong Buy/Sell signal")
fig.add_hline(y=-2, line_dash="dash", line_color="red")

fig.show(renderer="browser")

# %%
print(plot_data.index)

# %% [markdown]
# ## Подсчет Z-score индикатора

# %%
df_index.index = pd.to_datetime(df_index.index, format='mixed', utc=True)
df_index = df_index.sort_index()
df_index['mean'] = df_index['news_index'].rolling(window='1D').mean()
df_index['std'] = df_index['news_index'].rolling(window='1D').std()
df_index['z'] = (df_index['news_index'] - df_index['mean']) / df_index['std']

# %% [markdown]
# ## Визуализация - SBER IV, цена SBER vs INDEX (Z-score)

# %%
grp_index = df_index.groupby(pd.Grouper(freq='12h')).agg({'news_index': 'mean'})
sber = Ticker('SBER')

start_date = df_index.index.min().date()
end_date = df_index.index.max().date()

sber_candles = sber.candles(start=start_date, end=end_date, period='1h')
sber_candles['end'] = pd.to_datetime(sber_candles['end'])
options_df = pd.read_csv('sber_options_with_iv.csv')
options_df['date'] = pd.to_datetime(options_df['date'])

# %%
import plotly.graph_objects as go
import pandas as pd
import numpy as np
from plotly.subplots import make_subplots

# Строим график с двумя subplot'ами
fig = make_subplots(
    rows=2, cols=1,
    shared_xaxes=True,
    vertical_spacing=0.1,
    subplot_titles=('Курс акций Сбера', 'Новостной индикатор (Z-score)')
)

# Добавляем курс Сбера (без масштабирования, просто логарифм)
fig.add_trace(
    go.Scatter(
        x=sber_candles['end'], 
        y=sber_candles['close'], 
        mode='lines', 
        name='Цена акций Сбера',
        line=dict(color='blue', width=2),
        hovertemplate='Дата: %{x}<br>log(Цена): %{y:.3f}<extra>Цена акций</extra>'
    ),
    row=1, col=1
)

# Добавляем Z-score индикатор (без масштабирования, оригинальные значения)
fig.add_trace(
    go.Scatter(
        x=df_index.index, 
        y=df_index['news_index'], 
        mode='lines', 
        name='Новостной индикатор',
        line=dict(color='purple', width=2),
        hovertemplate='Дата: %{x}<br>Z-score: %{y:.3f}<extra></extra>'
    ),
    row=2, col=1
)

# Добавляем нулевую линию для Z-score (опционально)
fig.add_hline(
    y=0, 
    line_dash="dash", 
    line_color="gray", 
    opacity=0.5,
    row=2, col=1
)

# Улучшенный layout
fig.update_layout(
    title={
        'text': 'Сравнение курса Сбера и новостного индикатора',
        'x': 0.5,
        'xanchor': 'center',
        'font': dict(size=20)
    },
    hovermode='x unified',
    legend=dict(
        yanchor="top",
        y=0.99,
        xanchor="left",
        x=0.01,
        bgcolor='rgba(255, 255, 255, 0.8)'
    ),
    template='plotly_white',
    width=1200,
    height=700  # немного увеличил высоту для двух графиков
)

# Настройка осей
fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(count=3, label="3m", step="month", stepmode="backward"),
            dict(count=6, label="6m", step="month", stepmode="backward"),
            dict(count=1, label="YTD", step="year", stepmode="todate"),
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(step="all")
        ])
    ),
    row=2, col=1  # настройки для нижнего графика
)

# Настройка сетки для обоих графиков
fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='lightgray', row=1, col=1)
fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='lightgray', row=2, col=1)
fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='lightgray', row=2, col=1)

# Добавляем подписи осей
fig.update_yaxes(title_text="Цена", row=1, col=1)
fig.update_yaxes(title_text="Z-score", row=2, col=1)
fig.update_xaxes(title_text="Дата", row=2, col=1)

fig.show()

# %%
sber_candles['end']
print(df_index.index, type(df_index.index), sber_candles['end'].head(5), type(sber_candles['end']))
ardl_df = pd.merge(df_index, sber_candles, left_on=df_index.index, right_on=sber_candles['end'])

# %%
for row in df_index.itertuples():
    print((df_index.vector))
# Out:
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object
# 0       [-0.0004775062, 0.00043333505, -0.027657712, -...
# 1       [0.0028319352, -0.024047686, -0.013248004, -0....
# 2       [0.0010660948, -0.043258976, -0.024876593, -0....
# 3       [0.015571624, -0.011616255, -0.018180849, -0.0...
# 4       [0.0062406454, -0.022130735, -0.03741811, -0.0...
#                               ...
# 1299    [-0.009328682, -0.029091544, -0.05501606, -0.0...
# 1300    [0.0080741355, -0.008837929, -0.019202353, -0....
# 1301    [0.00038659017, -0.00084782456, -0.024314957, ...
# 1302    [-0.014119387, -0.045530323, -0.023710348, -0....
# 1303    [-0.017228842, 0.0035832056, -0.021458339, -0....
# Name: vector, Length: 1304, dtype: object

# %%
import faiss
import numpy as np

dimension = 1024
threshold = 0.92

for idx, groups in df_index.groupby('un_date'):
    day_embeddings = np.stack(group['vector'].values).astype('float32')
    index = faiss.IndexFlatIP(dimension)
    index.add(day_embeddings)
    # upper_boundary, down_boundary = groups.index[0], groups.index[-1]
    print(f'{'='*30}ПОИСК ПО {idx} ДНЮ')
    # print(upper_boundary, down_boundary)
    lims, dists, inds = index.range_search(day_embeddings, threshold)
    for row in groups.itertuples():
        # print(groups)
        summary_embedding = np.array([row.vector])
        
        lims, dists, inds = index.range_search(summary_embedding[down_boundary:upper_boundary+1], threshold)
        if len(inds) > 1:
            print(f'Для новости\n"{row.summary[:100]}..."\nнайдены соседи (первые 3)')
            for idx in inds[1:]:
                print(f'[{df_index.iloc[idx]['scraped_date']}] - {df_index.iloc[idx]['summary'][:100]}...\n')
        else:
            print(f'Не найдено новостей, похожих на:\n{df_index.iloc[inds[0]]['summary'][:100]}\n')
# Out:
# ====================
# 0 49
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[73], line 23
#      21         print(f'[{df_index.iloc[idx]['scraped_date']}] - {df_index.iloc[idx]['summary'][:100]}...\n')
#      22 else:
# ---> 23     print(f'Не найдено новостей, похожих на:\n{df_index.iloc[inds[0]]['summary'][:100]}\n')
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
import faiss
import numpy as np

dimension = 1024
threshold = 0.95
df_index['news_order'] = -1

# 1. Цикл по дням
for date_idx, group in df_index.groupby('un_date'):
    print(f"\n{'='*30}")
    print(f"Обработка дня: {date_idx}")
    
    # Готовим матрицу эмбеддингов только для ЭТОГО дня
    # Предполагаем, что в колонке 'vector' лежат списки или массивы
    day_embeddings = np.stack(group['vector'].values).astype('float32')
    
    # Создаем индекс специально для этого дня
    index = faiss.IndexFlatIP(dimension)
    index.add(day_embeddings)
    
    # 2. Ищем похожие новости внутри этого дня
    # Можно искать сразу для всей группы (это быстрее, чем циклом)
    lims, dists, inds = index.range_search(day_embeddings, threshold)
    
    # 3. Разбираем результаты
    for i in range(len(group)):
        # Получаем индексы соседей для i-й новости текущего дня
        start, end = lims[i], lims[i+1]
        neighbor_indices_in_day = inds[start:end]
        neighbor_dists = dists[start:end]
        
        # Исключаем саму себя (где индекс равен i)
        others_mask = neighbor_indices_in_day != i
        actual_neighbors = neighbor_indices_in_day[others_mask]
        
        if len(actual_neighbors) > 0:
            current_news = group.iloc[i]
            print(f"\nНовость: {current_news['summary'][:80]}...")
            print(f"Найдено дублей в этот день: {len(actual_neighbors)}")
            
            for neighbor_idx in actual_neighbors:
                neighbor_news = group.iloc[neighbor_idx]
                print(f"  -> [{neighbor_news['scraped_date']}] {neighbor_news['summary'][:60]}...")
# Out:
# ==============================
# Обработка дня: 2025-12-01
#
# Новость: Банковское обозрение (Б.О принт, BestPractice-онлайн (40 кейсов в год) + доступ ...
# Найдено дублей в этот день: 1
#   -> [2025-12-01 15:20:00+00:00] Сбербанк запустил возможность оплаты товаров и услуг в Китае...
#
# Новость: Как оплачивать покупки по QR-коду AliPay через Сбербанк Онлайн в Китае С 2022 го...
# Найдено дублей в этот день: 1
#   -> [2025-12-01 09:47:00+00:00] Сбербанк запустил оплату товаров и услуг в Китае через платф...
#
# Новость: Сбербанк запустил возможность оплаты товаров и услуг в Китае через QR-код в свое...
# Найдено дублей в этот день: 2
#   -> [2025-12-01 10:18:00+00:00] Банковское обозрение (Б.О принт, BestPractice-онлайн (40 кей...
#   -> [2025-12-01 09:47:00+00:00] Сбербанк запустил оплату товаров и услуг в Китае через платф...
#
# Новость: Сбербанк запустил оплату товаров и услуг в Китае через платформу Alipay с помощь...
# Найдено дублей в этот день: 2
#   -> [2025-12-01 21:34:00+00:00] Как оплачивать покупки по QR-коду AliPay через Сбербанк Онла...
#   -> [2025-12-01 15:20:00+00:00] Сбербанк запустил возможность оплаты товаров и услуг в Китае...
#
# ==============================
# Обработка дня: 2025-12-02
#
# Новость: БКС сообщила о начале обмена заблокированных иностранных акций на акции Сбербанк...
# Найдено дублей в этот день: 4
#   -> [2025-12-02 10:12:00+00:00] БКС собирает заявки на обмен заблокированных активов на акци...
#   -> [2025-12-02 09:56:00+00:00] БКС запускает обмен заблокированных активов на акции Сбербан...
#   -> [2025-12-02 06:50:00+00:00] БКС запустил обмен заблокированных иностранных акций на бума...
#   -> [2025-12-02 11:49:00+00:00] Новости декабрь 2025 БКС принимает заявки на обмен заморожен...
#
# Новость: БКС собирает заявки на обмен заблокированных активов на акции Сбербанка БКС нача...
# Найдено дублей в этот день: 5
#   -> [2025-12-02 00:32:00+00:00] БКС сообщила о начале обмена заблокированных иностранных акц...
#   -> [2025-12-02 09:56:00+00:00] БКС запускает обмен заблокированных активов на акции Сбербан...
#   -> [2025-12-02 11:06:00+00:00] Обмен доступен физическим лицам — резидентам РФ, которые дер...
#   -> [2025-12-02 06:50:00+00:00] БКС запустил обмен заблокированных иностранных акций на бума...
#   -> [2025-12-02 11:49:00+00:00] Новости декабрь 2025 БКС принимает заявки на обмен заморожен...
#
# Новость: БКС запускает обмен заблокированных активов на акции Сбербанка до декабря 2025 У...
# Найдено дублей в этот день: 5
#   -> [2025-12-02 00:32:00+00:00] БКС сообщила о начале обмена заблокированных иностранных акц...
#   -> [2025-12-02 10:12:00+00:00] БКС собирает заявки на обмен заблокированных активов на акци...
#   -> [2025-12-02 11:06:00+00:00] Обмен доступен физическим лицам — резидентам РФ, которые дер...
#   -> [2025-12-02 06:50:00+00:00] БКС запустил обмен заблокированных иностранных акций на бума...
#   -> [2025-12-02 11:49:00+00:00] Новости декабрь 2025 БКС принимает заявки на обмен заморожен...
#
# Новость: Обмен доступен физическим лицам — резидентам РФ, которые держали заблокированные...
# Найдено дублей в этот день: 2
#   -> [2025-12-02 10:12:00+00:00] БКС собирает заявки на обмен заблокированных активов на акци...
#   -> [2025-12-02 09:56:00+00:00] БКС запускает обмен заблокированных активов на акции Сбербан...
#
# Новость: БКС запустил обмен заблокированных иностранных акций на бумаги Сбербанка БКС объ...
# Найдено дублей в этот день: 3
#   -> [2025-12-02 00:32:00+00:00] БКС сообщила о начале обмена заблокированных иностранных акц...
#   -> [2025-12-02 10:12:00+00:00] БКС собирает заявки на обмен заблокированных активов на акци...
#   -> [2025-12-02 09:56:00+00:00] БКС запускает обмен заблокированных активов на акции Сбербан...
#
# Новость: Новости декабрь 2025 БКС принимает заявки на обмен замороженных ценных бумаг на ...
# Найдено дублей в этот день: 3
#   -> [2025-12-02 00:32:00+00:00] БКС сообщила о начале обмена заблокированных иностранных акц...
#   -> [2025-12-02 10:12:00+00:00] БКС собирает заявки на обмен заблокированных активов на акци...
#   -> [2025-12-02 09:56:00+00:00] БКС запускает обмен заблокированных активов на акции Сбербан...
#
# ==============================
# Обработка дня: 2025-12-03
#
# ==============================
# Обработка дня: 2025-12-04
#
# Новость: По его словам, банк ждет одобрения регулятора на открытие в стране 10 отделений....
# Найдено дублей в этот день: 1
#   -> [2025-12-04 18:17:00+00:00] По его словам, банк ждет одобрения регулятора на открытие в ...
#
# Новость: Сбербанк планирует расширить бизнес в Индии Москва. 4 декабря. Сбербанк также хо...
# Найдено дублей в этот день: 1
#   -> [2025-12-04 16:11:00+00:00] Сбербанк планирует расширить бизнес в Индии Москва. 4 декабр...
#
# Новость: Сбербанк и Changan провели первую в России полностью безбумажную сделку по авток...
# Найдено дублей в этот день: 1
#   -> [2025-12-04 13:26:00+00:00] Сбербанк и Changan провели первую в России полностью безбума...
#
# Новость: Сбер и УК «Первая» первыми в России открывают частным инвесторам доступ к фондов...
# Найдено дублей в этот день: 2
#   -> [2025-12-04 14:15:00+00:00] Сбербанк открывает российским инвесторам доступ к индийскому...
#   -> [2025-12-04 14:15:00+00:00] Сбербанк открывает российским инвесторам доступ к индийскому...
#
# Новость: На маркетплейсе Сбербанка средняя стоимость ОСАГО с начала года снизилась на 5% ...
# Найдено дублей в этот день: 1
#   -> [2025-12-04 10:30:00+00:00] На маркетплейсе Сбербанка средняя стоимость ОСАГО с начала г...
#
# Новость: Представители вузов обсудили с экспертами Сбера трансформацию образования на юге...
# Найдено дублей в этот день: 1
#   -> [2025-12-04 17:48:00+00:00] Представители вузов обсудили с экспертами Сбера трансформаци...
#
# Новость: Сбербанк внедрил новую услугу, позволяющую его клиентам оплачивать товары и услу...
# Найдено дублей в этот день: 1
#   -> [2025-12-04 08:08:00+00:00] Сбербанк внедрил новую услугу, позволяющую его клиентам опла...
#
# Новость: Сбербанк открывает российским инвесторам доступ к индийскому фондовому рынку "Сб...
# Найдено дублей в этот день: 2
#   -> [2025-12-04 14:30:00+00:00] Сбер и УК «Первая» первыми в России открывают частным инвест...
#   -> [2025-12-04 14:15:00+00:00] Сбербанк открывает российским инвесторам доступ к индийскому...
#
# Новость: Владимирское отделение ПАО «Сбербанк» получило статуэтку на премии «Владимирский...
# Найдено дублей в этот день: 1
#   -> [2025-12-04 18:19:00+00:00] Владимирское отделение ПАО «Сбербанк» получило статуэтку на ...
#
# Новость: По его словам, банк ждет одобрения регулятора на открытие в стране 10 отделений....
# Найдено дублей в этот день: 1
#   -> [2025-12-04 18:17:00+00:00] По его словам, банк ждет одобрения регулятора на открытие в ...
#
# Новость: Сбербанк планирует расширить бизнес в Индии Москва. 4 декабря. Сбербанк также хо...
# Найдено дублей в этот день: 1
#   -> [2025-12-04 16:11:00+00:00] Сбербанк планирует расширить бизнес в Индии Москва. 4 декабр...
#
# Новость: Представители вузов обсудили с экспертами Сбера трансформацию образования на юге...
# Найдено дублей в этот день: 1
#   -> [2025-12-04 17:48:00+00:00] Представители вузов обсудили с экспертами Сбера трансформаци...
#
# Новость: Сбербанк и Changan провели первую в России полностью безбумажную сделку по авток...
# Найдено дублей в этот день: 1
#   -> [2025-12-04 13:26:00+00:00] Сбербанк и Changan провели первую в России полностью безбума...
#
# Новость: На маркетплейсе Сбербанка средняя стоимость ОСАГО с начала года снизилась на 5% ...
# Найдено дублей в этот день: 1
#   -> [2025-12-04 10:30:00+00:00] На маркетплейсе Сбербанка средняя стоимость ОСАГО с начала г...
#
# Новость: Сбербанк внедрил новую услугу, позволяющую его клиентам оплачивать товары и услу...
# Найдено дублей в этот день: 1
#   -> [2025-12-04 10:08:00+00:00] Сбербанк внедрил новую услугу, позволяющую его клиентам опла...
#
# Новость: Сбербанк открывает российским инвесторам доступ к индийскому фондовому рынку "Сб...
# Найдено дублей в этот день: 2
#   -> [2025-12-04 14:30:00+00:00] Сбер и УК «Первая» первыми в России открывают частным инвест...
#   -> [2025-12-04 14:15:00+00:00] Сбербанк открывает российским инвесторам доступ к индийскому...
#
# Новость: Владимирское отделение ПАО «Сбербанк» получило статуэтку на премии «Владимирский...
# Найдено дублей в этот день: 1
#   -> [2025-12-04 18:19:00+00:00] Владимирское отделение ПАО «Сбербанк» получило статуэтку на ...
#
# ==============================
# Обработка дня: 2025-12-05
#
# ==============================
# Обработка дня: 2025-12-06
#
# ==============================
# Обработка дня: 2025-12-07
#
# ==============================
# Обработка дня: 2025-12-08
#
# ==============================
# Обработка дня: 2025-12-10
#
# Новость: Председатель правления Сбербанка Герман Греф заявил, что банк сохраняет план по ...
# Найдено дублей в этот день: 1
#   -> [2025-12-10 11:58:00+00:00] INTERFAX.RU - Сбербанк прогнозирует рентабельность капитала ...
#
# Новость: INTERFAX.RU - Сбербанк прогнозирует рентабельность капитала в 2026 году на уровн...
# Найдено дублей в этот день: 1
#   -> [2025-12-10 12:27:00+00:00] Председатель правления Сбербанка Герман Греф заявил, что бан...
#
# Новость: Сбербанк ожидает эффект от внедрения ИИ в 2026 году в размере 550 млрд рублей Мо...
# Найдено дублей в этот день: 1
#   -> [2025-12-10 15:48:00+00:00] Сбербанк ожидает эффекта от внедрения ИИ в 2026 г. в размере...
#
# Новость: Сбербанк обновил приложение «СберИнвестиции» для iOS, оно называется Petfolio, с...
# Найдено дублей в этот день: 1
#   -> [2025-12-10 13:50:00+00:00] Сбербанк обновил приложение для инвесторов на iOS — установи...
#
# Новость: Ключевая ставка в России может снизиться до 12% к концу 2026 года, заявил в рамк...
# Найдено дублей в этот день: 2
#   -> [2025-12-10 11:14:00+00:00] 10 декабря. INTERFAX.RU - Сбербанк в 2026 году прогнозирует ...
#   -> [2025-12-10 09:18:00+00:00] Греф дал прогноз по ключевой ставке Греф заявил, что рост ро...
#
# Новость: 10 декабря. INTERFAX.RU - Сбербанк в 2026 году прогнозирует сдержанный рост экон...
# Найдено дублей в этот день: 3
#   -> [2025-12-10 08:54:00+00:00] Ключевая ставка в России может снизиться до 12% к концу 2026...
#   -> [2025-12-10 09:51:00+00:00] Герман Греф, Президент, Председатель Правления Сбербанка: Эк...
#   -> [2025-12-10 09:18:00+00:00] Греф дал прогноз по ключевой ставке Греф заявил, что рост ро...
#
# Новость: Сбербанк ожидает эффекта от внедрения ИИ в 2026 г. в размере 550 млрд рублей Ран...
# Найдено дублей в этот день: 1
#   -> [2025-12-10 11:34:00+00:00] Сбербанк ожидает эффект от внедрения ИИ в 2026 году в размер...
#
# Новость: Сбербанк обновил приложение для инвесторов на iOS — установите новую версию, пок...
# Найдено дублей в этот день: 1
#   -> [2025-12-10 14:24:00+00:00] Сбербанк обновил приложение «СберИнвестиции» для iOS, оно на...
#
# Новость: Герман Греф, Президент, Председатель Правления Сбербанка: Экономика, инфляция и ...
# Найдено дублей в этот день: 1
#   -> [2025-12-10 11:14:00+00:00] 10 декабря. INTERFAX.RU - Сбербанк в 2026 году прогнозирует ...
#
# Новость: Греф дал прогноз по ключевой ставке Греф заявил, что рост российской экономики в...
# Найдено дублей в этот день: 2
#   -> [2025-12-10 08:54:00+00:00] Ключевая ставка в России может снизиться до 12% к концу 2026...
#   -> [2025-12-10 11:14:00+00:00] 10 декабря. INTERFAX.RU - Сбербанк в 2026 году прогнозирует ...
#
# ==============================
# Обработка дня: 2025-12-11
#
# Новость: INTERFAX.RU - Сбербанк надеется на допуск стейблкоинов, в первую очередь на рубл...
# Найдено дублей в этот день: 2
#   -> [2025-12-11 12:27:00+00:00] Сбербанк планирует расширить использование стейблкоинов внут...
#   -> [2025-12-11 11:19:00+00:00] Сбербанк SBER активно работает с Центробанком над созданием ...
#
# Новость: Сбербанк планирует расширить использование стейблкоинов внутри России. REUTERS/D...
# Найдено дублей в этот день: 2
#   -> [2025-12-11 11:31:00+00:00] INTERFAX.RU - Сбербанк надеется на допуск стейблкоинов, в пе...
#   -> [2025-12-11 11:19:00+00:00] Сбербанк SBER активно работает с Центробанком над созданием ...
#
# Новость: Сбербанк SBER активно работает с Центробанком над созданием правовой среды для к...
# Найдено дублей в этот день: 2
#   -> [2025-12-11 11:31:00+00:00] INTERFAX.RU - Сбербанк надеется на допуск стейблкоинов, в пе...
#   -> [2025-12-11 12:27:00+00:00] Сбербанк планирует расширить использование стейблкоинов внут...
#
# ==============================
# Обработка дня: 2025-12-12
#
# Новость: Новое приложение Сбербанка удалено из App Store Партизанское приложение госбанка...
# Найдено дублей в этот день: 1
#   -> [2025-12-12 09:53:00+00:00] Сбербанк удалил приложение для iPhone из App Store после кра...
#
# Новость: Сбербанк удалил приложение для iPhone из App Store после краткого возвращения По...
# Найдено дублей в этот день: 1
#   -> [2025-12-12 05:28:00+00:00] Новое приложение Сбербанка удалено из App Store Партизанское...
#
# ==============================
# Обработка дня: 2025-12-13
#
# Новость: Жительница Брянска судится со Сбербанком из-за кредитки Жительница Брянска судит...
# Найдено дублей в этот день: 1
#   -> [2025-12-13 14:00:00+00:00] Жительница Брянска судится со Сбербанком из-за кредитки Жите...
#
# Новость: Теперь клиентов ждут не только улучшенные сервисы, но и дополнительные бонусы, в...
# Найдено дублей в этот день: 1
#   -> [2025-12-13 08:00:00+00:00] Теперь клиентов ждут не только улучшенные сервисы, но и допо...
#
# Новость: Почему это важно? Президент Владимир Путин в конце ноября подписал закон, которы...
# Найдено дублей в этот день: 1
#   -> [2025-12-13 05:30:00+00:00] Почему это важно? Президент Владимир Путин в конце ноября по...
#
# Новость: Под изменения в итоге попадут все клиенты, пользующиеся пластиковыми картами Сбе...
# Найдено дублей в этот день: 1
#   -> [2025-12-13 04:23:00+00:00] Под изменения в итоге попадут все клиенты, пользующиеся плас...
#
# Новость: Жительница Брянска судится со Сбербанком из-за кредитки Жительница Брянска судит...
# Найдено дублей в этот день: 1
#   -> [2025-12-13 14:00:00+00:00] Жительница Брянска судится со Сбербанком из-за кредитки Жите...
#
# Новость: Теперь клиентов ждут не только улучшенные сервисы, но и дополнительные бонусы, в...
# Найдено дублей в этот день: 1
#   -> [2025-12-13 08:00:00+00:00] Теперь клиентов ждут не только улучшенные сервисы, но и допо...
#
# Новость: Почему это важно? Президент Владимир Путин в конце ноября подписал закон, которы...
# Найдено дублей в этот день: 1
#   -> [2025-12-13 05:30:00+00:00] Почему это важно? Президент Владимир Путин в конце ноября по...
#
# Новость: Под изменения в итоге попадут все клиенты, пользующиеся пластиковыми картами Сбе...
# Найдено дублей в этот день: 1
#   -> [2025-12-13 04:23:00+00:00] Под изменения в итоге попадут все клиенты, пользующиеся плас...
#
# ==============================
# Обработка дня: 2025-12-14
#
# ==============================
# Обработка дня: 2025-12-15
#
# Новость: Сбербанк и Т-Банк планируют вывести на рынок новый сервис — перевод между гражда...
# Найдено дублей в этот день: 6
#   -> [2025-12-15 09:30:00+00:00] Сбербанк и Т-банк введут переводы между гражданами по QR-код...
#   -> [2025-12-15 03:13:00+00:00] Как стало известно «Ъ», Сбербанк (MOEX: SBER) и Т-Банк плани...
#   -> [2025-12-15 09:55:00+00:00] Т-банк и Сбербанк запускают переводы по QR-коду для удобства...
#   -> [2025-12-15 11:56:00+00:00] Межбанковские переводы по QR-коду ускорят транзакции клиенто...
#   -> [2025-12-15 06:10:00+00:00] Сбербанк и «Т-Банк» готовят запуск нового способа переводов ...
#   -> [2025-12-15 18:23:00+00:00] Сбер и Т-Банк запустят новый вид переводов по QR-коду: серви...
#
# Новость: Сбербанк и Т-банк введут переводы между гражданами по QR-коду Получатель средств...
# Найдено дублей в этот день: 6
#   -> [2025-12-15 09:58:00+00:00] Сбербанк и Т-Банк планируют вывести на рынок новый сервис — ...
#   -> [2025-12-15 03:13:00+00:00] Как стало известно «Ъ», Сбербанк (MOEX: SBER) и Т-Банк плани...
#   -> [2025-12-15 09:55:00+00:00] Т-банк и Сбербанк запускают переводы по QR-коду для удобства...
#   -> [2025-12-15 11:56:00+00:00] Межбанковские переводы по QR-коду ускорят транзакции клиенто...
#   -> [2025-12-15 06:10:00+00:00] Сбербанк и «Т-Банк» готовят запуск нового способа переводов ...
#   -> [2025-12-15 18:23:00+00:00] Сбер и Т-Банк запустят новый вид переводов по QR-коду: серви...
#
# Новость: Как стало известно «Ъ», Сбербанк (MOEX: SBER) и Т-Банк планируют вывести на рыно...
# Найдено дублей в этот день: 6
#   -> [2025-12-15 09:58:00+00:00] Сбербанк и Т-Банк планируют вывести на рынок новый сервис — ...
#   -> [2025-12-15 09:30:00+00:00] Сбербанк и Т-банк введут переводы между гражданами по QR-код...
#   -> [2025-12-15 09:55:00+00:00] Т-банк и Сбербанк запускают переводы по QR-коду для удобства...
#   -> [2025-12-15 11:56:00+00:00] Межбанковские переводы по QR-коду ускорят транзакции клиенто...
#   -> [2025-12-15 06:10:00+00:00] Сбербанк и «Т-Банк» готовят запуск нового способа переводов ...
#   -> [2025-12-15 18:23:00+00:00] Сбер и Т-Банк запустят новый вид переводов по QR-коду: серви...
#
# Новость: Т-банк и Сбербанк запускают переводы по QR-коду для удобства клиентов Запуск сер...
# Найдено дублей в этот день: 6
#   -> [2025-12-15 09:58:00+00:00] Сбербанк и Т-Банк планируют вывести на рынок новый сервис — ...
#   -> [2025-12-15 09:30:00+00:00] Сбербанк и Т-банк введут переводы между гражданами по QR-код...
#   -> [2025-12-15 03:13:00+00:00] Как стало известно «Ъ», Сбербанк (MOEX: SBER) и Т-Банк плани...
#   -> [2025-12-15 11:56:00+00:00] Межбанковские переводы по QR-коду ускорят транзакции клиенто...
#   -> [2025-12-15 06:10:00+00:00] Сбербанк и «Т-Банк» готовят запуск нового способа переводов ...
#   -> [2025-12-15 18:23:00+00:00] Сбер и Т-Банк запустят новый вид переводов по QR-коду: серви...
#
# Новость: Межбанковские переводы по QR-коду ускорят транзакции клиентов Т-Банка и Сбербанк...
# Найдено дублей в этот день: 6
#   -> [2025-12-15 09:58:00+00:00] Сбербанк и Т-Банк планируют вывести на рынок новый сервис — ...
#   -> [2025-12-15 09:30:00+00:00] Сбербанк и Т-банк введут переводы между гражданами по QR-код...
#   -> [2025-12-15 03:13:00+00:00] Как стало известно «Ъ», Сбербанк (MOEX: SBER) и Т-Банк плани...
#   -> [2025-12-15 09:55:00+00:00] Т-банк и Сбербанк запускают переводы по QR-коду для удобства...
#   -> [2025-12-15 06:10:00+00:00] Сбербанк и «Т-Банк» готовят запуск нового способа переводов ...
#   -> [2025-12-15 18:23:00+00:00] Сбер и Т-Банк запустят новый вид переводов по QR-коду: серви...
#
# Новость: Найден лучший способ потратить 13-ю зарплату Вклад в Сбербанке назван оптимальны...
# Найдено дублей в этот день: 1
#   -> [2025-12-15 23:48:00+00:00] Найден лучший способ потратить 13-ю зарплату Вклад в Сбербан...
#
# Новость: Сбербанк и «Т-Банк» готовят запуск нового способа переводов между гражданами — п...
# Найдено дублей в этот день: 6
#   -> [2025-12-15 09:58:00+00:00] Сбербанк и Т-Банк планируют вывести на рынок новый сервис — ...
#   -> [2025-12-15 09:30:00+00:00] Сбербанк и Т-банк введут переводы между гражданами по QR-код...
#   -> [2025-12-15 03:13:00+00:00] Как стало известно «Ъ», Сбербанк (MOEX: SBER) и Т-Банк плани...
#   -> [2025-12-15 09:55:00+00:00] Т-банк и Сбербанк запускают переводы по QR-коду для удобства...
#   -> [2025-12-15 11:56:00+00:00] Межбанковские переводы по QR-коду ускорят транзакции клиенто...
#   -> [2025-12-15 18:23:00+00:00] Сбер и Т-Банк запустят новый вид переводов по QR-коду: серви...
#
# Новость: Сбер и Т-Банк запустят новый вид переводов по QR-коду: сервис будет доступен для...
# Найдено дублей в этот день: 6
#   -> [2025-12-15 09:58:00+00:00] Сбербанк и Т-Банк планируют вывести на рынок новый сервис — ...
#   -> [2025-12-15 09:30:00+00:00] Сбербанк и Т-банк введут переводы между гражданами по QR-код...
#   -> [2025-12-15 03:13:00+00:00] Как стало известно «Ъ», Сбербанк (MOEX: SBER) и Т-Банк плани...
#   -> [2025-12-15 09:55:00+00:00] Т-банк и Сбербанк запускают переводы по QR-коду для удобства...
#   -> [2025-12-15 11:56:00+00:00] Межбанковские переводы по QR-коду ускорят транзакции клиенто...
#   -> [2025-12-15 06:10:00+00:00] Сбербанк и «Т-Банк» готовят запуск нового способа переводов ...
#
# Новость: Найден лучший способ потратить 13-ю зарплату Вклад в Сбербанке назван оптимальны...
# Найдено дублей в этот день: 1
#   -> [2025-12-15 23:48:00+00:00] Найден лучший способ потратить 13-ю зарплату Вклад в Сбербан...
#
# ==============================
# Обработка дня: 2025-12-16
#
# Новость: Полное погашение основного долга, а также просроченных процентов и неустоек план...
# Найдено дублей в этот день: 1
#   -> [2025-12-16 08:32:00+00:00] Полное погашение основного долга, а также просроченных проце...
#
# Новость: Подробный разбор для собственников земли: что такое сервитут, сколько он стоит, ...
# Найдено дублей в этот день: 1
#   -> [2025-12-16 08:17:00+00:00] Подробный разбор для собственников земли: что такое сервитут...
#
# Новость: Узнайте, как не потерять связь с редакцией. © ООО Региональные новости ПАО «Сбер...
# Найдено дублей в этот день: 1
#   -> [2025-12-16 12:32:00+00:00] Узнайте, как не потерять связь с редакцией. © ООО Региональн...
#
# Новость: Сбербанк оштрафован на 300 тысяч рублей за ненадлежащую рекламу в Пермском крае ...
# Найдено дублей в этот день: 1
#   -> [2025-12-16 12:12:00+00:00] Сбербанк оштрафован на 300 тысяч рублей за ненадлежащую рекл...
#
# Новость: Сбербанк получил часть бизнес-центра «Большевик» на Ленинградском проспекте Фина...
# Найдено дублей в этот день: 2
#   -> [2025-12-16 07:27:00+00:00] Сбербанк получил в собственность часть бизнес-центра «Больше...
#   -> [2025-12-16 00:36:00+00:00] Сбербанк получил часть бизнес-центра «Большевик» на Ленингра...
#
# Новость: «Тринадцатая зарплата», или новогодний денежный бонус — дополнительное вознаграж...
# Найдено дублей в этот день: 1
#   -> [2025-12-16 09:33:00+00:00] «Тринадцатая зарплата», или новогодний денежный бонус — допо...
#
# Новость: Минимальная сумма для открытия депозита составляет 100 тысяч рублей. Также дейст...
# Найдено дублей в этот день: 1
#   -> [2025-12-16 09:07:00+00:00] Минимальная сумма для открытия депозита составляет 100 тысяч...
#
# Новость: Банковское обозрение (Б.О принт, BestPractice-онлайн (40 кейсов в год) + доступ ...
# Найдено дублей в этот день: 1
#   -> [2025-12-16 18:31:00+00:00] Банковское обозрение (Б.О принт, BestPractice-онлайн (40 кей...
#
# Новость: Индекс заметности Сбербанка вырос на 13% по сравнению с предыдущим месяцем, ВТБ ...
# Найдено дублей в этот день: 1
#   -> [2025-12-16 12:22:00+00:00] Индекс заметности Сбербанка вырос на 13% по сравнению с пред...
#
# Новость: Сбербанк запускает оплату частями на биометрических терминалах Сбербанк представ...
# Найдено дублей в этот день: 2
#   -> [2025-12-16 22:12:00+00:00] Сбербанк запустил пилотный проект сервиса «Плати частями» на...
#   -> [2025-12-16 18:16:00+00:00] Сбербанк запускает оплату частями на биометрических терминал...
#
# Новость: Он открыл новую IT-школу на площадке технопарка Morion Digital. «Школа 21» — это...
# Найдено дублей в этот день: 1
#   -> [2025-12-16 18:30:00+00:00] Он открыл новую IT-школу на площадке технопарка Morion Digit...
#
# Новость: Сбербанк обратился в Арбитражный суд Курской области с заявлением о признании ба...
# Найдено дублей в этот день: 1
#   -> [2025-12-16 14:05:00+00:00] Сбербанк обратился в Арбитражный суд Курской области с заявл...
#
# Новость: Пользователи часто ищут инструкции: «сбербанк перевод на alipay» или «как пополн...
# Найдено дублей в этот день: 1
#   -> [2025-12-16 08:47:00+00:00] Пользователи часто ищут инструкции: «сбербанк перевод на ali...
#
# Новость: Бывший управляющий пензенским отделением Сбербанка погиб в страшном ДТП: прощани...
# Найдено дублей в этот день: 1
#   -> [2025-12-16 06:00:00+00:00] Бывший управляющий пензенским отделением Сбербанка погиб в с...
#
# Новость: В Свердловской области запущена процедура наблюдения в отношении ООО «Свердловск...
# Найдено дублей в этот день: 1
#   -> [2025-12-16 13:45:00+00:00] В Свердловской области запущена процедура наблюдения в отнош...
#
# Новость: Сбербанк получил в собственность часть бизнес-центра «Большевик», расположенного...
# Найдено дублей в этот день: 2
#   -> [2025-12-16 00:36:00+00:00] Сбербанк получил часть бизнес-центра «Большевик» на Ленингра...
#   -> [2025-12-16 00:36:00+00:00] Сбербанк получил часть бизнес-центра «Большевик» на Ленингра...
#
# Новость: С 17 декабря Сбербанк вводит важные изменения для всех клиентов, использующих ба...
# Найдено дублей в этот день: 1
#   -> [2025-12-16 04:30:00+00:00] С 17 декабря Сбербанк вводит важные изменения для всех клиен...
#
# Новость: Сбербанк назвал генеративный ИИ вопросом национального суверенитета — и это не п...
# Найдено дублей в этот день: 1
#   -> [2025-12-16 12:30:00+00:00] Сбербанк назвал генеративный ИИ вопросом национального сувер...
#
# Новость: Ранее такая возможность была доступна только внутри одного банка, сообщили в пре...
# Найдено дублей в этот день: 1
#   -> [2025-12-16 11:18:00+00:00] Ранее такая возможность была доступна только внутри одного б...
#
# Новость: Суд отложил иск Сбербанка к кипрской компании на 12,3 млн долларов Арбитражный с...
# Найдено дублей в этот день: 1
#   -> [2025-12-16 12:55:00+00:00] Суд отложил иск Сбербанка к кипрской компании на 12,3 млн до...
#
# Новость: Сбербанк запустил пилотный проект сервиса «Плати частями» на биометрических плат...
# Найдено дублей в этот день: 2
#   -> [2025-12-16 18:16:00+00:00] Сбербанк запускает оплату частями на биометрических терминал...
#   -> [2025-12-16 18:16:00+00:00] Сбербанк запускает оплату частями на биометрических терминал...
#
# Новость: Сбербанк получил часть бизнес-центра «Большевик» на Ленинградском проспекте Фина...
# Найдено дублей в этот день: 2
#   -> [2025-12-16 00:36:00+00:00] Сбербанк получил часть бизнес-центра «Большевик» на Ленингра...
#   -> [2025-12-16 07:27:00+00:00] Сбербанк получил в собственность часть бизнес-центра «Больше...
#
# Новость: Полное погашение основного долга, а также просроченных процентов и неустоек план...
# Найдено дублей в этот день: 1
#   -> [2025-12-16 08:32:00+00:00] Полное погашение основного долга, а также просроченных проце...
#
# Новость: Подробный разбор для собственников земли: что такое сервитут, сколько он стоит, ...
# Найдено дублей в этот день: 1
#   -> [2025-12-16 08:17:00+00:00] Подробный разбор для собственников земли: что такое сервитут...
#
# Новость: «Тринадцатая зарплата», или новогодний денежный бонус — дополнительное вознаграж...
# Найдено дублей в этот день: 1
#   -> [2025-12-16 09:33:00+00:00] «Тринадцатая зарплата», или новогодний денежный бонус — допо...
#
# Новость: Узнайте, как не потерять связь с редакцией. © ООО Региональные новости ПАО «Сбер...
# Найдено дублей в этот день: 1
#   -> [2025-12-16 12:32:00+00:00] Узнайте, как не потерять связь с редакцией. © ООО Региональн...
#
# Новость: Сбербанк оштрафован на 300 тысяч рублей за ненадлежащую рекламу в Пермском крае ...
# Найдено дублей в этот день: 1
#   -> [2025-12-16 12:12:00+00:00] Сбербанк оштрафован на 300 тысяч рублей за ненадлежащую рекл...
#
# Новость: Минимальная сумма для открытия депозита составляет 100 тысяч рублей. Также дейст...
# Найдено дублей в этот день: 1
#   -> [2025-12-16 09:07:00+00:00] Минимальная сумма для открытия депозита составляет 100 тысяч...
#
# Новость: Банковское обозрение (Б.О принт, BestPractice-онлайн (40 кейсов в год) + доступ ...
# Найдено дублей в этот день: 1
#   -> [2025-12-16 18:31:00+00:00] Банковское обозрение (Б.О принт, BestPractice-онлайн (40 кей...
#
# Новость: Индекс заметности Сбербанка вырос на 13% по сравнению с предыдущим месяцем, ВТБ ...
# Найдено дублей в этот день: 1
#   -> [2025-12-16 12:22:00+00:00] Индекс заметности Сбербанка вырос на 13% по сравнению с пред...
#
# Новость: Сбербанк запускает оплату частями на биометрических терминалах Сбербанк представ...
# Найдено дублей в этот день: 2
#   -> [2025-12-16 18:16:00+00:00] Сбербанк запускает оплату частями на биометрических терминал...
#   -> [2025-12-16 22:12:00+00:00] Сбербанк запустил пилотный проект сервиса «Плати частями» на...
#
# Новость: Он открыл новую IT-школу на площадке технопарка Morion Digital. «Школа 21» — это...
# Найдено дублей в этот день: 1
#   -> [2025-12-16 18:30:00+00:00] Он открыл новую IT-школу на площадке технопарка Morion Digit...
#
# Новость: Сбербанк обратился в Арбитражный суд Курской области с заявлением о признании ба...
# Найдено дублей в этот день: 1
#   -> [2025-12-16 14:05:00+00:00] Сбербанк обратился в Арбитражный суд Курской области с заявл...
#
# Новость: Пользователи часто ищут инструкции: «сбербанк перевод на alipay» или «как пополн...
# Найдено дублей в этот день: 1
#   -> [2025-12-16 08:47:00+00:00] Пользователи часто ищут инструкции: «сбербанк перевод на ali...
#
# Новость: Бывший управляющий пензенским отделением Сбербанка погиб в страшном ДТП: прощани...
# Найдено дублей в этот день: 1
#   -> [2025-12-16 06:00:00+00:00] Бывший управляющий пензенским отделением Сбербанка погиб в с...
#
# Новость: В Свердловской области запущена процедура наблюдения в отношении ООО «Свердловск...
# Найдено дублей в этот день: 1
#   -> [2025-12-16 13:45:00+00:00] В Свердловской области запущена процедура наблюдения в отнош...
#
# Новость: С 17 декабря Сбербанк вводит важные изменения для всех клиентов, использующих ба...
# Найдено дублей в этот день: 1
#   -> [2025-12-16 04:30:00+00:00] С 17 декабря Сбербанк вводит важные изменения для всех клиен...
#
# Новость: Сбербанк назвал генеративный ИИ вопросом национального суверенитета — и это не п...
# Найдено дублей в этот день: 1
#   -> [2025-12-16 12:30:00+00:00] Сбербанк назвал генеративный ИИ вопросом национального сувер...
#
# Новость: Ранее такая возможность была доступна только внутри одного банка, сообщили в пре...
# Найдено дублей в этот день: 1
#   -> [2025-12-16 11:18:00+00:00] Ранее такая возможность была доступна только внутри одного б...
#
# Новость: Суд отложил иск Сбербанка к кипрской компании на 12,3 млн долларов Арбитражный с...
# Найдено дублей в этот день: 1
#   -> [2025-12-16 12:55:00+00:00] Суд отложил иск Сбербанка к кипрской компании на 12,3 млн до...
#
# ==============================
# Обработка дня: 2025-12-17
#
# ==============================
# Обработка дня: 2025-12-18
#
# Новость: Сбербанк прогнозирует снижение ключевой ставки на 50-100 б. п. 19 декабря В ходе...
# Найдено дублей в этот день: 1
#   -> [2025-12-18 13:14:00+00:00] Последние поступающие данные по инфляции дают возможность Ба...
#
# Новость: Последние поступающие данные по инфляции дают возможность Банку России на заседа...
# Найдено дублей в этот день: 1
#   -> [2025-12-18 10:16:00+00:00] Сбербанк прогнозирует снижение ключевой ставки на 50-100 б. ...
#
# ==============================
# Обработка дня: 2025-12-19
#
# Новость: В Сбербанке сообщили о снижении с 22 декабря минимальной ставки по потребительск...
# Найдено дублей в этот день: 10
#   -> [2025-12-19 16:25:00+00:00] 19 декабря. ФИНМАРКЕТ - Сбербанк с 22 декабря снизит ставку ...
#   -> [2025-12-19 16:18:00+00:00] Сбербанк снижает ставки по кредитам вслед за решением ЦБ по ...
#   -> [2025-12-19 16:17:00+00:00] Это изменение обусловлено решением Центрального банка России...
#   -> [2025-12-19 19:13:00+00:00] Так, с 22 декабря «Сбер» снизит минимальную ставку потребите...
#   -> [2025-12-19 16:14:00+00:00] INTERFAX.RU - Сбербанк с 22 декабря снизит ставку по потребк...
#   -> [2025-12-19 18:30:00+00:00] В Сбербанке сообщили о снижении с 22 декабря минимальной ста...
#   -> [2025-12-19 16:25:00+00:00] 19 декабря. ФИНМАРКЕТ - Сбербанк с 22 декабря снизит ставку ...
#   -> [2025-12-19 16:18:00+00:00] Сбербанк снижает ставки по кредитам вслед за решением ЦБ по ...
#   -> [2025-12-19 16:17:00+00:00] Это изменение обусловлено решением Центрального банка России...
#   -> [2025-12-19 19:13:00+00:00] Так, с 22 декабря «Сбер» снизит минимальную ставку потребите...
#
# Новость: Лента Новостей Все новости →Структура экс-главы «Сбербанк Капитала» купила еще о...
# Найдено дублей в этот день: 1
#   -> [2025-12-19 00:00:00+00:00] Лента Новостей Все новости →Структура экс-главы «Сбербанк Ка...
#
# Новость: Сбербанк запустил персонального финансового помощника на базе нейросети «ГигаЧат...
# Найдено дублей в этот день: 1
#   -> [2025-12-19 12:28:00+00:00] Сбербанк запустил персонального финансового помощника на баз...
#
# Новость: ИНТЕРФАКС - Сбербанк России разместил два выпуска ипотечных облигаций с поручите...
# Найдено дублей в этот день: 1
#   -> [2025-12-19 17:00:00+00:00] ИНТЕРФАКС - Сбербанк России разместил два выпуска ипотечных ...
#
# Новость: «На его основе система формирует витрину с доступными товарами и продавцами», – ...
# Найдено дублей в этот день: 1
#   -> [2025-12-19 16:06:00+00:00] «На его основе система формирует витрину с доступными товара...
#
# Новость: По итогам года Сбер подтвердил статус крупнейшего налогоплательщика региона. В э...
# Найдено дублей в этот день: 1
#   -> [2025-12-19 18:07:00+00:00] По итогам года Сбер подтвердил статус крупнейшего налогоплат...
#
# Новость: Акции Сбербанка в четверг снизились на 0,51%, закрылись по 301,96 руб. Объем тор...
# Найдено дублей в этот день: 1
#   -> [2025-12-19 07:59:00+00:00] Акции Сбербанка в четверг снизились на 0,51%, закрылись по 3...
#
# Новость: 19 декабря. ФИНМАРКЕТ - Сбербанк с 22 декабря снизит ставку по потребкредитам на...
# Найдено дублей в этот день: 8
#   -> [2025-12-19 18:30:00+00:00] В Сбербанке сообщили о снижении с 22 декабря минимальной ста...
#   -> [2025-12-19 16:17:00+00:00] Это изменение обусловлено решением Центрального банка России...
#   -> [2025-12-19 19:13:00+00:00] Так, с 22 декабря «Сбер» снизит минимальную ставку потребите...
#   -> [2025-12-19 16:14:00+00:00] INTERFAX.RU - Сбербанк с 22 декабря снизит ставку по потребк...
#   -> [2025-12-19 18:30:00+00:00] В Сбербанке сообщили о снижении с 22 декабря минимальной ста...
#   -> [2025-12-19 16:25:00+00:00] 19 декабря. ФИНМАРКЕТ - Сбербанк с 22 декабря снизит ставку ...
#   -> [2025-12-19 16:17:00+00:00] Это изменение обусловлено решением Центрального банка России...
#   -> [2025-12-19 19:13:00+00:00] Так, с 22 декабря «Сбер» снизит минимальную ставку потребите...
#
# Новость: Сбербанк снижает ставки по кредитам вслед за решением ЦБ по ключевой ставке Сбер...
# Найдено дублей в этот день: 4
#   -> [2025-12-19 18:30:00+00:00] В Сбербанке сообщили о снижении с 22 декабря минимальной ста...
#   -> [2025-12-19 16:14:00+00:00] INTERFAX.RU - Сбербанк с 22 декабря снизит ставку по потребк...
#   -> [2025-12-19 18:30:00+00:00] В Сбербанке сообщили о снижении с 22 декабря минимальной ста...
#   -> [2025-12-19 16:18:00+00:00] Сбербанк снижает ставки по кредитам вслед за решением ЦБ по ...
#
# Новость: Это изменение обусловлено решением Центрального банка России, который в пятницу ...
# Найдено дублей в этот день: 6
#   -> [2025-12-19 18:30:00+00:00] В Сбербанке сообщили о снижении с 22 декабря минимальной ста...
#   -> [2025-12-19 16:25:00+00:00] 19 декабря. ФИНМАРКЕТ - Сбербанк с 22 декабря снизит ставку ...
#   -> [2025-12-19 16:14:00+00:00] INTERFAX.RU - Сбербанк с 22 декабря снизит ставку по потребк...
#   -> [2025-12-19 18:30:00+00:00] В Сбербанке сообщили о снижении с 22 декабря минимальной ста...
#   -> [2025-12-19 16:25:00+00:00] 19 декабря. ФИНМАРКЕТ - Сбербанк с 22 декабря снизит ставку ...
#   -> [2025-12-19 16:17:00+00:00] Это изменение обусловлено решением Центрального банка России...
#
# Новость: Так, с 22 декабря «Сбер» снизит минимальную ставку потребительских кредитов до 1...
# Найдено дублей в этот день: 6
#   -> [2025-12-19 18:30:00+00:00] В Сбербанке сообщили о снижении с 22 декабря минимальной ста...
#   -> [2025-12-19 16:25:00+00:00] 19 декабря. ФИНМАРКЕТ - Сбербанк с 22 декабря снизит ставку ...
#   -> [2025-12-19 16:14:00+00:00] INTERFAX.RU - Сбербанк с 22 декабря снизит ставку по потребк...
#   -> [2025-12-19 18:30:00+00:00] В Сбербанке сообщили о снижении с 22 декабря минимальной ста...
#   -> [2025-12-19 16:25:00+00:00] 19 декабря. ФИНМАРКЕТ - Сбербанк с 22 декабря снизит ставку ...
#   -> [2025-12-19 19:13:00+00:00] Так, с 22 декабря «Сбер» снизит минимальную ставку потребите...
#
# Новость: ЦБ приостановил обмен заблокированных активов на акции Сбербанка без разрешения ...
# Найдено дублей в этот день: 1
#   -> [2025-12-19 18:53:00+00:00] ЦБ приостановил обмен заблокированных активов на акции Сберб...
#
# Новость: Что изменится при входе в «Сбербанк Онлайн» с 20 декабря Упор на вход через подт...
# Найдено дублей в этот день: 1
#   -> [2025-12-19 04:30:00+00:00] Что изменится при входе в «Сбербанк Онлайн» с 20 декабря Упо...
#
# Новость: INTERFAX.RU - Сбербанк с 22 декабря снизит ставку по потребкредитам на 0,5 проце...
# Найдено дублей в этот день: 10
#   -> [2025-12-19 18:30:00+00:00] В Сбербанке сообщили о снижении с 22 декабря минимальной ста...
#   -> [2025-12-19 16:25:00+00:00] 19 декабря. ФИНМАРКЕТ - Сбербанк с 22 декабря снизит ставку ...
#   -> [2025-12-19 16:18:00+00:00] Сбербанк снижает ставки по кредитам вслед за решением ЦБ по ...
#   -> [2025-12-19 16:17:00+00:00] Это изменение обусловлено решением Центрального банка России...
#   -> [2025-12-19 19:13:00+00:00] Так, с 22 декабря «Сбер» снизит минимальную ставку потребите...
#   -> [2025-12-19 18:30:00+00:00] В Сбербанке сообщили о снижении с 22 декабря минимальной ста...
#   -> [2025-12-19 16:25:00+00:00] 19 декабря. ФИНМАРКЕТ - Сбербанк с 22 декабря снизит ставку ...
#   -> [2025-12-19 16:18:00+00:00] Сбербанк снижает ставки по кредитам вслед за решением ЦБ по ...
#   -> [2025-12-19 16:17:00+00:00] Это изменение обусловлено решением Центрального банка России...
#   -> [2025-12-19 19:13:00+00:00] Так, с 22 декабря «Сбер» снизит минимальную ставку потребите...
#
# Новость: Страховые компании Сбера – «СберСтрахование жизни» и «СберСтрахование» – выплати...
# Найдено дублей в этот день: 1
#   -> [2025-12-19 16:38:00+00:00] Страховые компании Сбера – «СберСтрахование жизни» и «СберСт...
#
# Новость: Правкомиссия не получала заявок на сделки по обмену заблокированных активов на а...
# Найдено дублей в этот день: 1
#   -> [2025-12-19 18:32:00+00:00] Правкомиссия не получала заявок на сделки по обмену заблокир...
#
# Новость: Сбербанк совместно с Т-банком запустил новый сервис переводов между банками с ис...
# Найдено дублей в этот день: 1
#   -> [2025-12-19 19:40:00+00:00] Сбербанк совместно с Т-банком запустил новый сервис переводо...
#
# Новость: С 10 декабря Сбербанк массово урезал кредитные лимиты по картам для клиентов. Об...
# Найдено дублей в этот день: 1
#   -> [2025-12-19 12:07:00+00:00] С 10 декабря Сбербанк массово урезал кредитные лимиты по кар...
#
# Новость: Разделом «Авто» в «Сбербанк онлайн» в 2025 году воспользовались 5,5 млн россиян ...
# Найдено дублей в этот день: 1
#   -> [2025-12-19 16:09:00+00:00] Разделом «Авто» в «Сбербанк онлайн» в 2025 году воспользовал...
#
# Новость: В Сбербанке сообщили о снижении с 22 декабря минимальной ставки по потребительск...
# Найдено дублей в этот день: 10
#   -> [2025-12-19 18:30:00+00:00] В Сбербанке сообщили о снижении с 22 декабря минимальной ста...
#   -> [2025-12-19 16:25:00+00:00] 19 декабря. ФИНМАРКЕТ - Сбербанк с 22 декабря снизит ставку ...
#   -> [2025-12-19 16:18:00+00:00] Сбербанк снижает ставки по кредитам вслед за решением ЦБ по ...
#   -> [2025-12-19 16:17:00+00:00] Это изменение обусловлено решением Центрального банка России...
#   -> [2025-12-19 19:13:00+00:00] Так, с 22 декабря «Сбер» снизит минимальную ставку потребите...
#   -> [2025-12-19 16:14:00+00:00] INTERFAX.RU - Сбербанк с 22 декабря снизит ставку по потребк...
#   -> [2025-12-19 16:25:00+00:00] 19 декабря. ФИНМАРКЕТ - Сбербанк с 22 декабря снизит ставку ...
#   -> [2025-12-19 16:18:00+00:00] Сбербанк снижает ставки по кредитам вслед за решением ЦБ по ...
#   -> [2025-12-19 16:17:00+00:00] Это изменение обусловлено решением Центрального банка России...
#   -> [2025-12-19 19:13:00+00:00] Так, с 22 декабря «Сбер» снизит минимальную ставку потребите...
#
# Новость: Лента Новостей Все новости →Структура экс-главы «Сбербанк Капитала» купила еще о...
# Найдено дублей в этот день: 1
#   -> [2025-12-19 00:00:00+00:00] Лента Новостей Все новости →Структура экс-главы «Сбербанк Ка...
#
# Новость: Сбербанк запустил персонального финансового помощника на базе нейросети «ГигаЧат...
# Найдено дублей в этот день: 1
#   -> [2025-12-19 12:28:00+00:00] Сбербанк запустил персонального финансового помощника на баз...
#
# Новость: ИНТЕРФАКС - Сбербанк России разместил два выпуска ипотечных облигаций с поручите...
# Найдено дублей в этот день: 1
#   -> [2025-12-19 17:00:00+00:00] ИНТЕРФАКС - Сбербанк России разместил два выпуска ипотечных ...
#
# Новость: «На его основе система формирует витрину с доступными товарами и продавцами», – ...
# Найдено дублей в этот день: 1
#   -> [2025-12-19 16:06:00+00:00] «На его основе система формирует витрину с доступными товара...
#
# Новость: По итогам года Сбер подтвердил статус крупнейшего налогоплательщика региона. В э...
# Найдено дублей в этот день: 1
#   -> [2025-12-19 18:07:00+00:00] По итогам года Сбер подтвердил статус крупнейшего налогоплат...
#
# Новость: Акции Сбербанка в четверг снизились на 0,51%, закрылись по 301,96 руб. Объем тор...
# Найдено дублей в этот день: 1
#   -> [2025-12-19 07:59:00+00:00] Акции Сбербанка в четверг снизились на 0,51%, закрылись по 3...
#
# Новость: 19 декабря. ФИНМАРКЕТ - Сбербанк с 22 декабря снизит ставку по потребкредитам на...
# Найдено дублей в этот день: 8
#   -> [2025-12-19 18:30:00+00:00] В Сбербанке сообщили о снижении с 22 декабря минимальной ста...
#   -> [2025-12-19 16:25:00+00:00] 19 декабря. ФИНМАРКЕТ - Сбербанк с 22 декабря снизит ставку ...
#   -> [2025-12-19 16:17:00+00:00] Это изменение обусловлено решением Центрального банка России...
#   -> [2025-12-19 19:13:00+00:00] Так, с 22 декабря «Сбер» снизит минимальную ставку потребите...
#   -> [2025-12-19 16:14:00+00:00] INTERFAX.RU - Сбербанк с 22 декабря снизит ставку по потребк...
#   -> [2025-12-19 18:30:00+00:00] В Сбербанке сообщили о снижении с 22 декабря минимальной ста...
#   -> [2025-12-19 16:17:00+00:00] Это изменение обусловлено решением Центрального банка России...
#   -> [2025-12-19 19:13:00+00:00] Так, с 22 декабря «Сбер» снизит минимальную ставку потребите...
#
# Новость: Сбербанк снижает ставки по кредитам вслед за решением ЦБ по ключевой ставке Сбер...
# Найдено дублей в этот день: 4
#   -> [2025-12-19 18:30:00+00:00] В Сбербанке сообщили о снижении с 22 декабря минимальной ста...
#   -> [2025-12-19 16:18:00+00:00] Сбербанк снижает ставки по кредитам вслед за решением ЦБ по ...
#   -> [2025-12-19 16:14:00+00:00] INTERFAX.RU - Сбербанк с 22 декабря снизит ставку по потребк...
#   -> [2025-12-19 18:30:00+00:00] В Сбербанке сообщили о снижении с 22 декабря минимальной ста...
#
# Новость: Это изменение обусловлено решением Центрального банка России, который в пятницу ...
# Найдено дублей в этот день: 6
#   -> [2025-12-19 18:30:00+00:00] В Сбербанке сообщили о снижении с 22 декабря минимальной ста...
#   -> [2025-12-19 16:25:00+00:00] 19 декабря. ФИНМАРКЕТ - Сбербанк с 22 декабря снизит ставку ...
#   -> [2025-12-19 16:17:00+00:00] Это изменение обусловлено решением Центрального банка России...
#   -> [2025-12-19 16:14:00+00:00] INTERFAX.RU - Сбербанк с 22 декабря снизит ставку по потребк...
#   -> [2025-12-19 18:30:00+00:00] В Сбербанке сообщили о снижении с 22 декабря минимальной ста...
#   -> [2025-12-19 16:25:00+00:00] 19 декабря. ФИНМАРКЕТ - Сбербанк с 22 декабря снизит ставку ...
#
# Новость: Так, с 22 декабря «Сбер» снизит минимальную ставку потребительских кредитов до 1...
# Найдено дублей в этот день: 6
#   -> [2025-12-19 18:30:00+00:00] В Сбербанке сообщили о снижении с 22 декабря минимальной ста...
#   -> [2025-12-19 16:25:00+00:00] 19 декабря. ФИНМАРКЕТ - Сбербанк с 22 декабря снизит ставку ...
#   -> [2025-12-19 19:13:00+00:00] Так, с 22 декабря «Сбер» снизит минимальную ставку потребите...
#   -> [2025-12-19 16:14:00+00:00] INTERFAX.RU - Сбербанк с 22 декабря снизит ставку по потребк...
#   -> [2025-12-19 18:30:00+00:00] В Сбербанке сообщили о снижении с 22 декабря минимальной ста...
#   -> [2025-12-19 16:25:00+00:00] 19 декабря. ФИНМАРКЕТ - Сбербанк с 22 декабря снизит ставку ...
#
# Новость: ЦБ приостановил обмен заблокированных активов на акции Сбербанка без разрешения ...
# Найдено дублей в этот день: 1
#   -> [2025-12-19 18:53:00+00:00] ЦБ приостановил обмен заблокированных активов на акции Сберб...
#
# Новость: Что изменится при входе в «Сбербанк Онлайн» с 20 декабря Упор на вход через подт...
# Найдено дублей в этот день: 1
#   -> [2025-12-19 04:30:00+00:00] Что изменится при входе в «Сбербанк Онлайн» с 20 декабря Упо...
#
# Новость: Страховые компании Сбера – «СберСтрахование жизни» и «СберСтрахование» – выплати...
# Найдено дублей в этот день: 1
#   -> [2025-12-19 16:38:00+00:00] Страховые компании Сбера – «СберСтрахование жизни» и «СберСт...
#
# Новость: Правкомиссия не получала заявок на сделки по обмену заблокированных активов на а...
# Найдено дублей в этот день: 1
#   -> [2025-12-19 18:32:00+00:00] Правкомиссия не получала заявок на сделки по обмену заблокир...
#
# Новость: Сбербанк совместно с Т-банком запустил новый сервис переводов между банками с ис...
# Найдено дублей в этот день: 1
#   -> [2025-12-19 19:40:00+00:00] Сбербанк совместно с Т-банком запустил новый сервис переводо...
#
# Новость: С 10 декабря Сбербанк массово урезал кредитные лимиты по картам для клиентов. Об...
# Найдено дублей в этот день: 1
#   -> [2025-12-19 12:07:00+00:00] С 10 декабря Сбербанк массово урезал кредитные лимиты по кар...
#
# Новость: Разделом «Авто» в «Сбербанк онлайн» в 2025 году воспользовались 5,5 млн россиян ...
# Найдено дублей в этот день: 1
#   -> [2025-12-19 16:09:00+00:00] Разделом «Авто» в «Сбербанк онлайн» в 2025 году воспользовал...
#
# ==============================
# Обработка дня: 2025-12-20
#
# ==============================
# Обработка дня: 2025-12-21
#
# Новость: Сбербанк начал массово снижать кредитные лимиты по картам для части своих клиент...
# Найдено дублей в этот день: 1
#   -> [2025-12-21 13:37:00+00:00] Начиная с 10 декабря, Сбербанк начал массово сокращать лимит...
#
# Новость: Сбербанк в конце декабря ввёл в пилотную эксплуатацию новый сервис «Плати частям...
# Найдено дублей в этот день: 1
#   -> [2025-12-21 21:13:00+00:00] Сбербанк в конце декабря ввёл в пилотную эксплуатацию новый ...
#
# Новость: Начиная с 10 декабря, Сбербанк начал массово сокращать лимиты по кредитным карта...
# Найдено дублей в этот день: 1
#   -> [2025-12-21 08:00:00+00:00] Сбербанк начал массово снижать кредитные лимиты по картам дл...
#
# Новость: Сбербанк в конце декабря ввёл в пилотную эксплуатацию новый сервис «Плати частям...
# Найдено дублей в этот день: 1
#   -> [2025-12-21 21:13:00+00:00] Сбербанк в конце декабря ввёл в пилотную эксплуатацию новый ...
#
# ==============================
# Обработка дня: 2025-12-22
#
# Новость: Крупнейшие банки отреагировали на снижение ключевой ставки ЦБ улучшением условий...
# Найдено дублей в этот день: 1
#   -> [2025-12-22 10:20:00+00:00] Крупнейшие банки отреагировали на снижение ключевой ставки Ц...
#
# Новость: "Благодаря антифрод-системе за 2025 год мы помогли россиянам уберечь от мошенник...
# Найдено дублей в этот день: 1
#   -> [2025-12-22 08:53:00+00:00] "Благодаря антифрод-системе за 2025 год мы помогли россиянам...
#
# Новость: В Рязани открылся обновлённый офис Сбербанка В Рязани открылся обновлённый офис ...
# Найдено дублей в этот день: 1
#   -> [2025-12-22 15:45:00+00:00] В Рязани открылся обновлённый офис Сбербанка В Рязани открыл...
#
# Новость: Сбербанк оштрафован на 800 тыс. рублей за скрытые условия в рекламе - 22 декабря...
# Найдено дублей в этот день: 2
#   -> [2025-12-22 08:45:00+00:00] Сбербанк оштрафован на 800 тыс. рублей за скрытые условия в ...
#   -> [2025-12-22 11:42:00+00:00] ПАО «Сбербанк» выписали штрафы на 800 тысяч рублей за наруше...
#
# Новость: В ожидании рекордных дивидендов финансовые результаты компании остаются устойчив...
# Найдено дублей в этот день: 1
#   -> [2025-12-22 20:48:00+00:00] В ожидании рекордных дивидендов финансовые результаты компан...
#
# Новость: Сбер начал давать бесплатные консультации по налогам Сбербанк расширил линейку с...
# Найдено дублей в этот день: 1
#   -> [2025-12-22 09:54:00+00:00] Сбер начал давать бесплатные консультации по налогам Сбербан...
#
# Новость: Получать пенсию в Сбере не только удобно, но и выгодно, обслуживание счета беспл...
# Найдено дублей в этот день: 1
#   -> [2025-12-22 11:00:00+00:00] Получать пенсию в Сбере не только удобно, но и выгодно, обсл...
#
# Новость: Даже пенсию и социальные выплаты теперь можно получать прямо на карту. Кроме тог...
# Найдено дублей в этот день: 1
#   -> [2025-12-22 10:45:00+00:00] Даже пенсию и социальные выплаты теперь можно получать прямо...
#
# Новость: Крупнейшие банки отреагировали на снижение ключевой ставки ЦБ улучшением условий...
# Найдено дублей в этот день: 1
#   -> [2025-12-22 10:20:00+00:00] Крупнейшие банки отреагировали на снижение ключевой ставки Ц...
#
# Новость: "Благодаря антифрод-системе за 2025 год мы помогли россиянам уберечь от мошенник...
# ...
#   -> [2026-02-12 11:41:00+00:00] На Международном конгрессе госуправления глава Сбербанка зая...
#
# ==============================
# Обработка дня: 2026-02-13
#
# Новость: Девятый арбитражный суд взыскал с ПАО «Сбербанк» свыше 1,4 млрд рублей по иску о...
# Найдено дублей в этот день: 1
#   -> [2026-02-13 09:23:00+00:00] Девятый арбитражный апелляционный суд удовлетворил апелляцио...
#
# Новость: Суд взыскал со «Сбера» 1,45 млрд рублей за нарушение прав PayQR на знаки обслужи...
# Найдено дублей в этот день: 2
#   -> [2026-02-13 09:57:00+00:00] Суд признал Сбербанк нарушившим исключительные права на брен...
#   -> [2026-02-13 20:38:00+00:00] СБЕРБАНК [новости] НОВОСТИ АКЦИЙ РОССИИ Победа PayQR: апелля...
#
# Новость: Суд признал Сбербанк нарушившим исключительные права на бренд PayQR Девятый арби...
# Найдено дублей в этот день: 2
#   -> [2026-02-13 15:38:00+00:00] Суд взыскал со «Сбера» 1,45 млрд рублей за нарушение прав Pa...
#   -> [2026-02-13 20:38:00+00:00] СБЕРБАНК [новости] НОВОСТИ АКЦИЙ РОССИИ Победа PayQR: апелля...
#
# Новость: Девятый арбитражный апелляционный суд удовлетворил апелляционную жалобу ООО «ФИТ...
# Найдено дублей в этот день: 2
#   -> [2026-02-13 19:18:00+00:00] Девятый арбитражный суд взыскал с ПАО «Сбербанк» свыше 1,4 м...
#   -> [2026-02-13 20:38:00+00:00] СБЕРБАНК [новости] НОВОСТИ АКЦИЙ РОССИИ Победа PayQR: апелля...
#
# Новость: СБЕРБАНК [новости] НОВОСТИ АКЦИЙ РОССИИ Победа PayQR: апелляция обязала Сбербанк...
# Найдено дублей в этот день: 3
#   -> [2026-02-13 15:38:00+00:00] Суд взыскал со «Сбера» 1,45 млрд рублей за нарушение прав Pa...
#   -> [2026-02-13 09:57:00+00:00] Суд признал Сбербанк нарушившим исключительные права на брен...
#   -> [2026-02-13 09:23:00+00:00] Девятый арбитражный апелляционный суд удовлетворил апелляцио...
#
# ==============================
# Обработка дня: 2026-02-14
#
# Новость: Сбербанк заявил о намерении требовать банкротства разработчика российского корпо...
# Найдено дублей в этот день: 1
#   -> [2026-02-14 15:08:00+00:00] Сбербанк заявил о намерении требовать банкротства разработчи...
#
# Новость: YakutiaMedia, 14 февраля. Управляющий Якутским отделением Сбербанка Олег Бугай, ...
# Найдено дублей в этот день: 1
#   -> [2026-02-14 08:00:00+00:00] YakutiaMedia, 14 февраля. Управляющий Якутским отделением Сб...
#
# Новость: Банк предложил государству механизм, который ускоряет выплаты гражданам и усилив...
# Найдено дублей в этот день: 1
#   -> [2026-02-14 12:08:00+00:00] Банк предложил государству механизм, который ускоряет выплат...
#
# Новость: СБЕРБАНК [анализ] [SBER] АНАЛИЗ АКЦИЙ РОССИИ Актуальный технический долгосрочный...
# Найдено дублей в этот день: 1
#   -> [2026-02-14 21:50:00+00:00] СБЕРБАНК [анализ] [SBER] АНАЛИЗ АКЦИЙ РОССИИ Актуальный техн...
#
# Новость: В частности, СберБанк списывает за уведомления личные средства клиентов. Причем ...
# Найдено дублей в этот день: 1
#   -> [2026-02-14 15:00:00+00:00] В частности, СберБанк списывает за уведомления личные средст...
#
# Новость: Сбербанк заявил о намерении требовать банкротства разработчика российского корпо...
# Найдено дублей в этот день: 1
#   -> [2026-02-14 15:08:00+00:00] Сбербанк заявил о намерении требовать банкротства разработчи...
#
# Новость: YakutiaMedia, 14 февраля. Управляющий Якутским отделением Сбербанка Олег Бугай, ...
# Найдено дублей в этот день: 1
#   -> [2026-02-14 08:00:00+00:00] YakutiaMedia, 14 февраля. Управляющий Якутским отделением Сб...
#
# Новость: Банк предложил государству механизм, который ускоряет выплаты гражданам и усилив...
# Найдено дублей в этот день: 1
#   -> [2026-02-14 12:08:00+00:00] Банк предложил государству механизм, который ускоряет выплат...
#
# Новость: СБЕРБАНК [анализ] [SBER] АНАЛИЗ АКЦИЙ РОССИИ Актуальный технический долгосрочный...
# Найдено дублей в этот день: 1
#   -> [2026-02-14 21:50:00+00:00] СБЕРБАНК [анализ] [SBER] АНАЛИЗ АКЦИЙ РОССИИ Актуальный техн...
#
# Новость: В частности, СберБанк списывает за уведомления личные средства клиентов. Причем ...
# Найдено дублей в этот день: 1
#   -> [2026-02-14 15:00:00+00:00] В частности, СберБанк списывает за уведомления личные средст...
#
# ==============================
# Обработка дня: 2026-02-15
#
# Новость: 🔸 ВТБ улучшил условия по кредитам наличными после решения ЦБ. 🔸 ЦБ изменил прогн...
# Найдено дублей в этот день: 1
#   -> [2026-02-15 00:00:00+00:00] 🔸 ВТБ улучшил условия по кредитам наличными после решения ЦБ...
#
# Новость: 🔸 ВТБ улучшил условия по кредитам наличными после решения ЦБ. 🔸 ЦБ изменил прогн...
# Найдено дублей в этот день: 1
#   -> [2026-02-15 00:00:00+00:00] 🔸 ВТБ улучшил условия по кредитам наличными после решения ЦБ...
#
# ==============================
# Обработка дня: 2026-02-16
#
# ==============================
# Обработка дня: 2026-02-17
#
# Новость: Дивиденды • 17 февраля в 14:11 Разбираемся, за счёт чего могут увеличиться выпла...
# Найдено дублей в этот день: 1
#   -> [2026-02-17 14:11:00+00:00] Дивиденды • 17 февраля в 14:11 Разбираемся, за счёт чего мог...
#
# Новость: Стала известна предположительная сумма взятки топ-менеджеру Сбера Собеседники по...
# Найдено дублей в этот день: 1
#   -> [2026-02-17 18:21:00+00:00] Стала известна предположительная сумма взятки топ-менеджеру ...
#
# Новость: ООО СХП «Поломское» (Кирово-Чепецкий район) — молочное животноводство. Выручка 4...
# Найдено дублей в этот день: 1
#   -> [2026-02-17 18:54:00+00:00] ООО СХП «Поломское» (Кирово-Чепецкий район) — молочное живот...
#
# Новость: Источник: Родиона Казмалы задержали в Сургуте, его жену — в Кирове Как нам сообщ...
# Найдено дублей в этот день: 1
#   -> [2026-02-17 21:47:00+00:00] Источник: Родиона Казмалы задержали в Сургуте, его жену — в ...
#
# Новость: Последняя подача документов от 3 февраля 2026 года сообщает, что "Документы прин...
# Найдено дублей в этот день: 1
#   -> [2026-02-17 16:22:00+00:00] 3) Никаких вопросов или уточнений от банка не приступало за ...
#
# Новость: Дивиденды • 17 февраля в 14:11 Разбираемся, за счёт чего могут увеличиться выпла...
# Найдено дублей в этот день: 1
#   -> [2026-02-17 14:11:00+00:00] Дивиденды • 17 февраля в 14:11 Разбираемся, за счёт чего мог...
#
# Новость: Стала известна предположительная сумма взятки топ-менеджеру Сбера Собеседники по...
# Найдено дублей в этот день: 1
#   -> [2026-02-17 18:21:00+00:00] Стала известна предположительная сумма взятки топ-менеджеру ...
#
# Новость: ООО СХП «Поломское» (Кирово-Чепецкий район) — молочное животноводство. Выручка 4...
# Найдено дублей в этот день: 1
#   -> [2026-02-17 18:54:00+00:00] ООО СХП «Поломское» (Кирово-Чепецкий район) — молочное живот...
#
# Новость: Источник: Родиона Казмалы задержали в Сургуте, его жену — в Кирове Как нам сообщ...
# Найдено дублей в этот день: 1
#   -> [2026-02-17 21:47:00+00:00] Источник: Родиона Казмалы задержали в Сургуте, его жену — в ...
#
# Новость: 3) Никаких вопросов или уточнений от банка не приступало за полтора года 4) Фраз...
# Найдено дублей в этот день: 1
#   -> [2026-02-17 16:22:00+00:00] Последняя подача документов от 3 февраля 2026 года сообщает,...
#
# ==============================
# Обработка дня: 2026-02-18
#
# ==============================
# Обработка дня: 2026-02-19
#
# ==============================
# Обработка дня: 2026-02-20
#
# Новость: Клиенты Сбербанка в 2025 году заработали на вкладах и накопительных счетах 868,9...
# Найдено дублей в этот день: 1
#   -> [2026-02-20 19:07:00+00:00] Клиенты Сбербанка в 2025 году заработали на вкладах и накопи...
#
# Новость: Новый механизм позволяет банкам в режиме реального времени автоматически обменив...
# Найдено дублей в этот день: 1
#   -> [2026-02-20 16:12:00+00:00] Новый механизм позволяет банкам в режиме реального времени а...
#
# Новость: Изменения касаются лимитов, комиссий и порядка проведения межбанковских операций...
# Найдено дублей в этот день: 1
#   -> [2026-02-20 04:30:00+00:00] Изменения касаются лимитов, комиссий и порядка проведения ме...
#
# Новость: Как сообщает abiznews, стороны подписали соглашение о намерениях, определяющее о...
# Найдено дублей в этот день: 1
#   -> [2026-02-20 20:54:00+00:00] Как сообщает abiznews, стороны подписали соглашение о намере...
#
# Новость: СБЕРБАНК [анализ] [SBER] АНАЛИЗ АКЦИЙ РОССИИ ПАО Сбербанк: количество физлиц-уча...
# Найдено дублей в этот день: 1
#   -> [2026-02-20 19:23:00+00:00] СБЕРБАНК [анализ] [SBER] АНАЛИЗ АКЦИЙ РОССИИ ПАО Сбербанк: к...
#
# Новость: Как будет работать Сбербанк В «Сбере» график сохранится по стандартной схеме: - ...
# Найдено дублей в этот день: 1
#   -> [2026-02-20 15:26:00+00:00] Как будет работать Сбербанк В «Сбере» график сохранится по с...
#
# Новость: Клиенты Сбербанка в 2025 году заработали на вкладах и накопительных счетах 868,9...
# Найдено дублей в этот день: 1
#   -> [2026-02-20 19:07:00+00:00] Клиенты Сбербанка в 2025 году заработали на вкладах и накопи...
#
# Новость: Изменения касаются лимитов, комиссий и порядка проведения межбанковских операций...
# Найдено дублей в этот день: 1
#   -> [2026-02-20 04:30:00+00:00] Изменения касаются лимитов, комиссий и порядка проведения ме...
#
# Новость: Новый механизм позволяет банкам в режиме реального времени автоматически обменив...
# Найдено дублей в этот день: 1
#   -> [2026-02-20 16:12:00+00:00] Новый механизм позволяет банкам в режиме реального времени а...
#
# Новость: Как сообщает abiznews, стороны подписали соглашение о намерениях, определяющее о...
# Найдено дублей в этот день: 1
#   -> [2026-02-20 20:54:00+00:00] Как сообщает abiznews, стороны подписали соглашение о намере...
#
# Новость: СБЕРБАНК [анализ] [SBER] АНАЛИЗ АКЦИЙ РОССИИ ПАО Сбербанк: количество физлиц-уча...
# Найдено дублей в этот день: 1
#   -> [2026-02-20 19:23:00+00:00] СБЕРБАНК [анализ] [SBER] АНАЛИЗ АКЦИЙ РОССИИ ПАО Сбербанк: к...
#
# Новость: Как будет работать Сбербанк В «Сбере» график сохранится по стандартной схеме: - ...
# Найдено дублей в этот день: 1
#   -> [2026-02-20 17:26:00+00:00] Как будет работать Сбербанк В «Сбере» график сохранится по с...
#
# Новость: ВТБ [новости] НОВОСТИ АКЦИЙ РОССИИ ВТБ не собирается выпускать дополнительные ак...
# Найдено дублей в этот день: 1
#   -> [2026-02-20 16:01:00+00:00] БАЗИС [новости] НОВОСТИ АКЦИЙ РОССИИ 25 февраля МСФО за 2025...
#
# Новость: БАЗИС [новости] НОВОСТИ АКЦИЙ РОССИИ 25 февраля МСФО за 2025 год 25 февраля МСФО...
# Найдено дублей в этот день: 1
#   -> [2026-02-20 13:05:00+00:00] ВТБ [новости] НОВОСТИ АКЦИЙ РОССИИ ВТБ не собирается выпуска...
#
# ==============================
# Обработка дня: 2026-02-21
#
# ==============================
# Обработка дня: 2026-02-22
#
# ==============================
# Обработка дня: 2026-02-23
#
# Новость: СБЕРБАНК [анализ] [SBER] АНАЛИЗ АКЦИЙ РОССИИ Акции Сбербанка готовы к росту: от ...
# Найдено дублей в этот день: 1
#   -> [2026-02-23 21:24:00+00:00] СБЕРБАНК [анализ] [SBER] АНАЛИЗ АКЦИЙ РОССИИ Акции Сбербанка...
#
# Новость: У них нет ни времени, ни желания просто так болтать с клиентами. Важный нюанс: е...
# Найдено дублей в этот день: 1
#   -> [2026-02-23 02:14:00+00:00] У них нет ни времени, ни желания просто так болтать с клиент...
#
# Новость: У них нет ни времени, ни желания просто так болтать с клиентами. Важный нюанс: е...
# Найдено дублей в этот день: 1
#   -> [2026-02-23 02:14:00+00:00] У них нет ни времени, ни желания просто так болтать с клиент...
#
# Новость: СБЕРБАНК [анализ] [SBER] АНАЛИЗ АКЦИЙ РОССИИ Акции Сбербанка готовы к росту: от ...
# Найдено дублей в этот день: 1
#   -> [2026-02-23 21:24:00+00:00] СБЕРБАНК [анализ] [SBER] АНАЛИЗ АКЦИЙ РОССИИ Акции Сбербанка...
#
# ==============================
# Обработка дня: 2026-02-24
#
# Новость: Акции Сбербанка в понедельник прибавили 0,05% и закрылись по 314,16 руб. Объем т...
# Найдено дублей в этот день: 1
#   -> [2026-02-24 11:42:00+00:00] Мнение: БКС Экспресс Прогноз по акциям Сбербанка Акции Сберб...
#
# Новость: Мнение: БКС Экспресс Прогноз по акциям Сбербанка Акции Сбербанка в понедельник в...
# Найдено дублей в этот день: 1
#   -> [2026-02-24 07:59:00+00:00] Акции Сбербанка в понедельник прибавили 0,05% и закрылись по...
#
# ==============================
# Обработка дня: 2026-02-25
#
# Новость: Сбербанк снизит ставки по рыночной ипотеке с 26 февраля Сбербанк решил с 26 февр...
# Найдено дублей в этот день: 4
#   -> [2026-02-25 16:22:00+00:00] Сбербанк снизил ставки по рыночной ипотеке Другие крупные ба...
#   -> [2026-02-25 14:58:00+00:00] «С 26 февраля „Сбер“ снижает ставки по рыночной ипотеке до 0...
#   -> [2026-02-25 19:14:00+00:00] БАНКИ РОССИИ [новости] НОВОСТИ ЭКОНОМИКИ РОССИИ Доступнее ип...
#   -> [2026-02-25 13:35:00+00:00] С 26 февраля Сбер смягчает условия по базовым ипотечным прод...
#
# Новость: Сбербанк снизил ставки по рыночной ипотеке Другие крупные банки пересматривали с...
# Найдено дублей в этот день: 3
#   -> [2026-02-25 14:08:00+00:00] Сбербанк снизит ставки по рыночной ипотеке с 26 февраля Сбер...
#   -> [2026-02-25 14:58:00+00:00] «С 26 февраля „Сбер“ снижает ставки по рыночной ипотеке до 0...
#   -> [2026-02-25 19:14:00+00:00] БАНКИ РОССИИ [новости] НОВОСТИ ЭКОНОМИКИ РОССИИ Доступнее ип...
#
# Новость: «С 26 февраля „Сбер“ снижает ставки по рыночной ипотеке до 0,7 п.п.: на 0,5 п.п....
# Найдено дублей в этот день: 5
#   -> [2026-02-25 14:08:00+00:00] Сбербанк снизит ставки по рыночной ипотеке с 26 февраля Сбер...
#   -> [2026-02-25 16:22:00+00:00] Сбербанк снизил ставки по рыночной ипотеке Другие крупные ба...
#   -> [2026-02-25 14:54:00+00:00] С 26 февраля 2026 года СберБанк снижает ставки по базовым ип...
#   -> [2026-02-25 19:14:00+00:00] БАНКИ РОССИИ [новости] НОВОСТИ ЭКОНОМИКИ РОССИИ Доступнее ип...
#   -> [2026-02-25 13:35:00+00:00] С 26 февраля Сбер смягчает условия по базовым ипотечным прод...
#
# Новость: С 26 февраля 2026 года СберБанк снижает ставки по базовым ипотечным программам д...
# Найдено дублей в этот день: 2
#   -> [2026-02-25 14:58:00+00:00] «С 26 февраля „Сбер“ снижает ставки по рыночной ипотеке до 0...
#   -> [2026-02-25 13:35:00+00:00] С 26 февраля Сбер смягчает условия по базовым ипотечным прод...
#
# Новость: БАНКИ РОССИИ [новости] НОВОСТИ ЭКОНОМИКИ РОССИИ Доступнее ипотека от Сбербанка: ...
# Найдено дублей в этот день: 4
#   -> [2026-02-25 14:08:00+00:00] Сбербанк снизит ставки по рыночной ипотеке с 26 февраля Сбер...
#   -> [2026-02-25 16:22:00+00:00] Сбербанк снизил ставки по рыночной ипотеке Другие крупные ба...
#   -> [2026-02-25 14:58:00+00:00] «С 26 февраля „Сбер“ снижает ставки по рыночной ипотеке до 0...
#   -> [2026-02-25 13:35:00+00:00] С 26 февраля Сбер смягчает условия по базовым ипотечным прод...
#
# Новость: С 26 февраля Сбер смягчает условия по базовым ипотечным продуктам, снизив процен...
# Найдено дублей в этот день: 4
#   -> [2026-02-25 14:08:00+00:00] Сбербанк снизит ставки по рыночной ипотеке с 26 февраля Сбер...
#   -> [2026-02-25 14:58:00+00:00] «С 26 февраля „Сбер“ снижает ставки по рыночной ипотеке до 0...
#   -> [2026-02-25 14:54:00+00:00] С 26 февраля 2026 года СберБанк снижает ставки по базовым ип...
#   -> [2026-02-25 19:14:00+00:00] БАНКИ РОССИИ [новости] НОВОСТИ ЭКОНОМИКИ РОССИИ Доступнее ип...
#
# ==============================
# Обработка дня: 2026-02-26
#
# Новость: Акции остаются нашим фаворитом на текущий год. ✔️ Чистые процентные доходы увели...
# Найдено дублей в этот день: 1
#   -> [2026-02-26 10:26:00+00:00] За IV квартал прошлого года показатель возрос на 12,9% год к...
#
# Новость: За четвертый квартал прибыль Сбербанка по МСФО выросла на 12,9%, до 398,6 млрд р...
# Найдено дублей в этот день: 1
#   -> [2026-02-26 10:39:00+00:00] Финансовые результаты Чистые процентные доходы Сбербанка уве...
#
# Новость: Сбербанк наращивает траты на персонал, несмотря на сокращения За 2025 год Сберба...
# Найдено дублей в этот день: 1
#   -> [2026-02-26 20:27:00+00:00] СБЕРБАНК [новости] НОВОСТИ АКЦИЙ РОССИИ Сбербанк наращивает ...
#
# Новость: За IV квартал прошлого года показатель возрос на 12,9% год к году и составил 399...
# Найдено дублей в этот день: 1
#   -> [2026-02-26 11:24:00+00:00] Акции остаются нашим фаворитом на текущий год. ✔️ Чистые про...
#
# Новость: Финансовые результаты Чистые процентные доходы Сбербанка увеличились в четвертом...
# Найдено дублей в этот день: 1
#   -> [2026-02-26 10:51:00+00:00] За четвертый квартал прибыль Сбербанка по МСФО выросла на 12...
#
# Новость: СБЕРБАНК [новости] НОВОСТИ АКЦИЙ РОССИИ Сбербанк наращивает траты на персонал, н...
# Найдено дублей в этот день: 1
#   -> [2026-02-26 09:41:00+00:00] Сбербанк наращивает траты на персонал, несмотря на сокращени...

# %%
import faiss
import numpy as np

# 1. Сортируем по времени — это критически важно для логики порядка
df_index = df_index.sort_values('scraped_date').reset_index(drop=True)
df_index['news_order'] = 1  # По умолчанию каждая новость — первая
df_index['similar_news'] = 0

dimension = 1024
threshold = 0.95

# 2. Обработка по дням
for date_val, group in df_index.groupby('un_date'):
    if len(group) < 2:
        continue
    
    # Извлекаем эмбеддинги для текущего дня (порядок совпадает с group)
    day_vectors = np.stack(group['vector'].values).astype('float32')
    faiss.normalize_L2(day_vectors)
    
    # Строим индекс для дня
    index = faiss.IndexFlatIP(dimension)
    index.add(day_vectors)
    
    # Ищем всех похожих внутри дня для всей группы сразу
    lims, dists, inds = index.range_search(day_vectors, threshold)
    
    # Список для хранения порядков текущего дня
    group_orders = []
    
    for i in range(len(group)):
        start, end = lims[i], lims[i+1]
        neighbor_indices_in_day = inds[start:end]
        neighbor_dists = dists[start:end]
        
        # Исключаем саму себя (где индекс равен i)
        others_mask = neighbor_indices_in_day != i
        actual_neighbors = neighbor_indices_in_day[others_mask]
        df_index.loc
        
        # Считаем, сколько похожих новостей имеют индекс меньше нашего (т.е. вышли раньше)
        # Если таких 0, то мы первые (0 + 1 = 1)
        # Если такая 1, то мы вторые (1 + 1 = 2) и так далее
        earlier_count = np.sum(neighbor_indices_in_day < i)
        group_orders.append(earlier_count + 1)
    
    # Записываем порядки обратно в основной DataFrame по индексам группы
    df_index.loc[group.index, 'news_order'] = group_orders

print("Расчет news_order завершен.")

# Проверка: посмотрим на те новости, которые не были первыми
duplicates = df_index[df_index['news_order'] > 1].sort_values(['un_date', 'news_order'])
if not duplicates.empty:
    print(f"Найдено дубликатов: {len(duplicates)}")
    display(duplicates[['scraped_date', 'news_order', 'title', 'source']].head(15))
else:
    print("Дубликатов с заданным порогом схожести не найдено.")
