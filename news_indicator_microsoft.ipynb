# %%
import pandas as pd
import numpy as np

# %%
news_df = pd.read_csv('сбербанк_3day_news.csv')
news_df['date'] = pd.to_datetime(news_df['date'])

# %%
news_df['date_column_cleaned'] = pd.to_datetime(news_df['scraped_date'], errors='coerce')

# Теперь удаляем строки, где преобразование не удалось
news_df = news_df.dropna(subset=['date_column_cleaned'])

# %%
news_df.head(30)

# %% [markdown]
# ## Форматирование scraped даты

# %%
months = {
    'январь': '01',
    'февраль': '02'
}

def process_date(date):
    possible_month = date.split()[0]
    for month in months.keys():
        if month in date:
            numerical_month = months.get(month)
            formatted_date = '-'.join(date.split()[0], numerical_month, date.split()[-1])
            return formatted_date

# %% [markdown]
# ## Модель Facebook для классификации

# %%
import torch
from transformers import pipeline

device = 0 if torch.cuda.is_available() else -1
print('Видюха поддерживается!') if device == 0 else print('Видюха НЕ поддерживается :(')
classifier = pipeline(
    "zero-shot-classification", 
    model="facebook/bart-large-mnli", 
    device=device
)

# %%
classified_dataset = 'sberbank_2d_facebook_model_class.csv'

# %% [markdown]
# #### Классификация summary текста

# %%
candidate_labels = ["Financials & Dividends", "Strategy & Corporate Events", "Market Analysis & Expert Forecasts", "Macro & Regulation",  "Retail Products & Marketing", "Service & Tech Updates"]

def process_news_batched(df, batch_size=8):
    df = df.copy()
    texts = df['summary'].tolist()
    
    all_results = []

    for i in range(0, len(texts), batch_size):
        batch_texts = texts[i:i + batch_size]
        
        batch_results = classifier(
            batch_texts, 
            candidate_labels, 
            multi_label=False
        )
        
        if isinstance(batch_results, dict):
            batch_results = [batch_results]
            
        all_results.extend(batch_results)
        print(f"Обработано {min(i + batch_size, len(texts))}/{len(texts)}")

    for label in candidate_labels:
        df[label] = [
            res['scores'][res['labels'].index(label)] 
            for res in all_results
        ]
        
    return df

news_df = process_news_batched(news_df, batch_size=8) # Начните с 4 для 1060
news_df.to_csv(classified_dataset)

# %%
def extract_publisher(title):
    return title.split(' - ')[-1]

unique_pubs = news_df['title'].apply(extract_publisher)
print(f'уникальные издания: {np.unique(unique_pubs)}')

# %% [markdown]
# ## Расчет Market Index

# %%
''' словарь с весами изданий '''
source_weights = {
    # --- TIER 1: Максимальное влияние (Институционалы, Биржи, ГосСМИ) ---
    'Интерфакс': 2.0,
    'Интерфакс Россия': 1.8,
    'Московская Биржа': 2.0,
    'Ведомости': 1.8,
    'Forbes.ru': 1.7,
    'Сбербанк': 1.7,
    'PJSC Sberbank': 1.7,
    'ОАО «Сбер Банк': 1.5,
    'Альфа-Банк': 1.5,
    'БКС Экспресс': 1.5,
    'Финам.Ру': 1.5,
    'Коммерсантъ': 1.8, # (Если появится в списке)
    'ПРАВО.Ru': 1.4,
    'РАПСИ': 1.3,

    # --- TIER 2: Профильные финансы, Технологии и Рынки ---
    'Investing.com': 1.3,
    'Smart-Lab': 1.3,
    'ProFinance': 1.3,
    'Банки.ру': 1.2,
    'Эксперт': 1.2,
    'Frank Media': 1.2,
    'InvestFuture': 1.1,
    'Finmarket.ru': 1.1,
    'CNews.ru': 1.1,
    'Хабр': 1.1,
    'iXBT.com': 1.0,
    '3DNews': 1.0,
    'CoinDesk': 1.0,
    'Zakon.ru': 1.0,
    'BFM.ru': 1.1,
    'Клерк.ру': 1.0,

    # --- TIER 3: Крупные агрегаторы и Федеральные СМИ ---
    'ФОНТАНКА.ру': 1.0,
    'URA.RU': 1.0,
    'NEWS.ru': 0.9,
    'Lenta.ru': 0.9, # (Если появится)
    'Т—Ж': 0.9,
    't-j.ru': 0.9,
    'Лайфхакер': 0.8,
    'Аргументы и Факты': 0.8,
    'БИЗНЕС Online — Новости Казани': 0.9,
    'Независимая газета': 0.9,
    'ФедералПресс': 0.8,
    'SIA.RU': 0.8,
    'Сибирское информационное агентство': 0.8,

    # --- TIER 4: Заметные региональные и отраслевые СМИ ---
    'НГС.ру': 0.7,
    '74.ру': 0.7,
    '59.ру': 0.7,
    'NGS.42': 0.7,
    'Алтапресс — новости Барнаула и Алтайского края': 0.6,
    'PrimaMedia': 0.6,
    'SakhalinMedia': 0.6,
    'ЯСИА': 0.6,
    'Сибкрай.ru': 0.6,
    'Vremyan.ru': 0.5,
    'Время Н': 0.5,
    'Выберу.ру': 0.5,
    'ВсеЗаймыОнлайн': 0.4,
    'ADIndex.ru': 0.5,
    'Sostav.ru': 0.5,
    'AppleInsider.ru': 0.5,

    # --- TIER 5: Мелкие региональные порталы и шум ---
    # Для всех остальных устанавливаем базовый низкий вес
}

# %%
indicator_pipe = pipeline(task='text-classification', model='ProsusAI/finbert')

# %%
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.lex_rank import LexRankSummarizer
from nltk.tokenize import sent_tokenize
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')

def get_summary(text, max_sentences):
    if not text or len(text) < 100: return "Текст слишком короткий"
    
    # 1. ПРЕДВАРИТЕЛЬНАЯ ЧИСТКА
    # Заменяем переносы строк на пробелы, чтобы склеенные строки разошлись
    clean_text = text.replace("\n", " ").replace("\r", " ")
    
    # Убираем лишние пробелы (два и более подряд)
    clean_text = " ".join(clean_text.split())

    try:
        # 2. Sumy выбирает "лучший кусок" текста
        parser = PlaintextParser.from_string(clean_text, Tokenizer("russian"))
        summarizer = LexRankSummarizer()
        
        # Просим Sumy дать 1 предложение. 
        # Но если токенизатор ошибся, Sumy вернет огромный кусок.
        sumy_result = summarizer(parser.document, max_sentences)
        raw_summary = " ".join([str(s) for s in sumy_result])
        
        # 3. ФИНАЛЬНАЯ НАРЕЗКА (SAFETY NET)
        # Мы берем то, что вернула Sumy, и еще раз режем на предложения через NLTK
        real_sentences = sent_tokenize(raw_summary, language="russian")
        
        if real_sentences:
            # Возвращаем СТРОГО первое предложение
            return ' '.join(real_sentences[:max_sentences])
        else:
            return raw_summary
            
    except Exception as e:
        print(f"Ошибка в NLP: {e}")
        return "Ошибка обработки"

def calculate_sentiment_index(neutral, positive, negative):
    sentiment_index = (positive * 1.0) + (neutral * 0.5) + (negative * 0.0)
    return round(sentiment_index, 4)

def calculate_market_index(summary):
    for length in range(4, 1, -1):
        try:
            print(f'пробуем длину {length}')
            short_summary = get_summary(summary, max_sentences=length)
            result_all = indicator_pipe(short_summary, top_k=None)
            idx = calculate_sentiment_index(result_all[0]['score'], result_all[1]['score'], result_all[2]['score'])
            return idx
        except Exception as e:
            if hasattr(str(e), 'Token indices sequence length') or hasattr(str(e), 'The size of tensor'):
                print('ошибка длины, сжимаем...')
                continue

# %%
index_dateset = 'sberbank_2d_facebook_model_class_with_index.csv'

# %%
df_index = pd.read_csv(classified_dataset)
df_index['news_index'] = df_index[df_index["Retail Products & Marketing"] + df_index["Service & Tech Updates"] < 0.3]['summary'].apply(calculate_market_index)

df_index.to_csv(index_dateset)

# %% [markdown]
# #### взвешенный индекс

# %%
def weight_index(index, publisher):
    if index is not None:
        coeff = source_weights.get(publisher, 1)
        return index * coeff
    return None

for idx, row in df_index.iterrows():
    publisher = (row['title']).split(' - ')[-1]
    df_index.at[idx, 'news_index'] = weight_index(
        index=row['news_index'], 
        publisher=publisher
    )

# %%
df_index['scraped_date'] = pd.to_datetime(df_index['scraped_date'], format='mixed', utc=True)
df_index.set_index(df_index['scraped_date'], inplace=True)
# df_index = df_index.drop(columns=['Unnamed: 0', 'scraped_date'])
df_index = df_index.drop(columns=['scraped_date'])

# %%
print(df_index.columns)
df_index = df_index.drop(columns=['Unnamed: 0'])
df_index

# %% [markdown]
# ## Эмбеддинг и кластеризация summary статей
# ### Модель - **intfloat/multilingual-e5-large**

# %%
df_index = pd.read_csv(index_dateset) # c посчитанным индексом

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('intfloat/multilingual-e5-large')

# %%
input_texts = [f"query: {text}" for text in df_index['summary']]
embeddings = model.encode(input_texts, normalize_embeddings=True)
print(f'embeddings:\n{embeddings[:10]} ...')

# %%
df_index['vector'] = [embeddings[i] for i in range(len(embeddings))]
np.save('embeddings.npy', embeddings)

# %% [markdown]
# ### Кластеризация эмбеддингов

# %%
index_dateset = 'sberbank_2d_facebook_model_class_with_index.csv'

# %%
import numpy as np
import pandas as pd

df_index = pd.read_csv(index_dateset)
embeddings = np.load('embeddings.npy')

df_index['scraped_date'] = pd.to_datetime(df_index['scraped_date'], format='mixed', utc=True)
# df_index.set_index(df_index['scraped_date'], inplace=True)
df_index = df_index.drop(columns=['Unnamed: 0', 'Unnamed: 0.1'])

# df_index = df_index.drop(columns=['scraped_date'])

# %%
df_index
# Out:
#                      date              scraped_date  \
# 0     2025-12-01 08:00:00 2025-12-01 13:56:00+00:00
# 1     2025-12-01 08:00:00 2025-12-01 13:08:00+00:00
# 2     2025-12-04 08:00:00 2025-12-04 18:17:00+00:00
# 3     2025-12-01 08:00:00 2025-12-01 13:45:00+00:00
# 4     2025-12-01 08:00:00 2025-12-01 17:49:00+00:00
# ...                   ...                       ...
# 1299  2026-02-24 08:00:00 2026-02-24 19:09:00+00:00
# 1300  2026-02-25 13:00:59 2026-02-25 13:00:00+00:00
# 1301  2026-02-25 10:35:59 2026-02-25 13:35:00+00:00
# 1302  2026-02-26 08:00:00 2026-02-26 16:53:00+00:00
# 1303  2026-02-25 14:54:24 2026-02-25 13:18:00+00:00
#
#                                                   title  \
# 0     Сбербанк запустил оплату по QR-коду в Китае - ...
# 1     В Сбербанке заявили, что более 6 тыс. компаний...
# 2     Сбербанк и ВТБ рассказали о планах развивать р...
# 3     Сбербанк: расчеты между РФ и Индией в нацвалют...
# 4     Сбербанк и ИТМО открыли коворкинг в историческ...
# ...                                                 ...
# 1299  Стоит ли открывать шорт по Сбербанку на текущи...
# 1300  Розничный кредитный портфель Сбербанка в Марий...
# 1301      Сбербанк снижает ставки по ипотеке - Zaim.com
# 1302  Греф дал прогноз по курсу доллара и назвал клю...
# 1303  Сбербанк сократил ставку по рыночной ипотеке д...
#
#                                                     url  \
# 0     https://expert.ru/news/sberbank-zapustil-oplat...
# 1             https://www.alta.ru/external_news/123771/
# 2     https://www.forbes.ru/finansy/551333-sberbank-...
# 3     https://finance.mail.ru/article/sberbank-rasch...
# 4     https://www.cnews.ru/news/line/2025-12-01_sber...
# ...                                                 ...
# 1299  https://news.mondiara.com/categories/18/posts/...
# 1300  https://potokmedia.ru/726126/roznichnyj-kredit...
# 1301  https://zaim.com/news/sberbank-snizhaet-stavki...
# 1302       https://www.fontanka.ru/2026/02/26/76284048/
# 1303  https://rznonline.ru/news/society/item/sberban...
#
#                                                 summary  date_column_cleaned  \
# 0     Курс конвертации отображается заранее. Один из...  2025-12-01 13:56:00
# 1     Более 6 тыс. индийских компаний заинтересованы...  2025-12-01 13:08:00
# 2     По его словам, банк ждет одобрения регулятора ...  2025-12-04 18:17:00
# 3     «Большая часть расчетов между Россией и Индией...  2025-12-01 13:45:00
# 4     Сбербанк и ИТМО открыли коворкинг в историческ...  2025-12-01 17:49:00
# ...                                                 ...                  ...
# 1299  СБЕРБАНК [анализ] [SBER] АНАЛИЗ АКЦИЙ РОССИИ С...  2026-02-24 19:09:00
# 1300  Портфель жилищных кредитов в Сбере вырос на 24...  2026-02-25 13:00:00
# 1301  С 26 февраля Сбер смягчает условия по базовым ...  2026-02-25 13:35:00
# 1302  Председатель правления Сбербанка Герман Греф д...  2026-02-26 16:53:00
# 1303  Сбербанк объявил о снижении ставок по рыночной...  2026-02-25 13:18:00
#
#       Financials & Dividends  Strategy & Corporate Events  \
# 0                   0.130606                     0.175752
# 1                   0.135380                     0.170500
# 2                   0.115787                     0.185119
# 3                   0.114892                     0.158577
# 4                   0.140714                     0.159085
# ...                      ...                          ...
# 1299                0.166520                     0.166248
# 1300                0.122723                     0.187904
# 1301                0.135873                     0.139189
# 1302                0.157583                     0.178149
# 1303                0.125435                     0.168364
#
#       Market Analysis & Expert Forecasts  Macro & Regulation  \
# 0                               0.196811            0.203383
# 1                               0.202823            0.202666
# 2                               0.192532            0.213854
# 3                               0.197901            0.212726
# 4                               0.164817            0.241957
# ...                                  ...                 ...
# 1299                            0.216415            0.226594
# 1300                            0.192907            0.206225
# 1301                            0.216225            0.228763
# 1302                            0.194156            0.203276
# 1303                            0.172147            0.242958
#
#       Retail Products & Marketing  Service & Tech Updates  news_index
# 0                        0.113176                0.180273      0.5803
# 1                        0.093650                0.194980      0.5576
# 2                        0.106043                0.186663      0.5678
# 3                        0.086506                0.229398         NaN
# 4                        0.101167                0.192260      0.6076
# ...                           ...                     ...         ...
# 1299                     0.065674                0.158549      0.5637
# 1300                     0.096391                0.193849      0.5622
# 1301                     0.090029                0.189922      0.5370
# 1302                     0.092517                0.174320      0.5847
# 1303                     0.094904                0.196192      0.5709
#
# [1304 rows x 13 columns]

# %%
df_index['vector'] = list(embeddings)
df_index = df_index.drop_duplicates(subset='summary')

# %%
df_index['un_date'] = pd.to_datetime(df_index['scraped_date']).dt.date

# %%
import umap
import hdbscan

reducer = umap.UMAP(
    n_components=3, 
    n_neighbors=5, 
    metric='cosine', 
    random_state=42
)

embedding = reducer.fit_transform(df_index['vector'].values.tolist())
df_index['x'] = embedding[:, 0]
df_index['y'] = embedding[:, 1]
df_index['z'] = embedding[:, 2]

for idx, group in df_index.groupby('un_date'):
    if len(group) < 5:
        continue
    vectors = np.stack(group[['x','y','z']].values)
    clusterer = hdbscan.HDBSCAN(
        min_cluster_size=5,
        allow_single_cluster=True,
        cluster_selection_method='eom',
        metric='euclidean'
    )
    labels = clusterer.fit_predict(vectors)

    df_index.loc[group.index, 'cluster_id'] = labels
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import umap
#       2 import hdbscan
#       4 reducer = umap.UMAP(
#       5     n_components=3,
#       6     n_neighbors=5,
#       7     metric='cosine',
#       8     random_state=42
#       9 )
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/umap/__init__.py:2
#       1 from warnings import warn, catch_warnings, simplefilter
# ----> 2 from .umap_ import UMAP
#       4 try:
#       5     with catch_warnings():
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/umap/umap_.py:48
#      41 from umap.spectral import spectral_layout, tswspectral_layout
#      42 from umap.layouts import (
#      43     optimize_layout_euclidean,
#      44     optimize_layout_generic,
#      45     optimize_layout_inverse,
#      46 )
# ---> 48 from pynndescent import NNDescent
#      49 from pynndescent.distances import named_distances as pynn_named_distances
#      50 from pynndescent.sparse import sparse_named_distances as pynn_sparse_named_distances
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/pynndescent/__init__.py:5
#       1 import sys
#       3 import numba
# ----> 5 from .pynndescent_ import NNDescent, PyNNDescentTransformer
#       7 if sys.version_info[:2] >= (3, 8):
#       8     import importlib.metadata as importlib_metadata
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/pynndescent/pynndescent_.py:22
#      12 from scipy.sparse import (
#      13     csr_matrix,
#      14     coo_matrix,
#    (...)     17     issparse,
#      18 )
#      20 import heapq
# ---> 22 import pynndescent.sparse as sparse
#      23 import pynndescent.sparse_nndescent as sparse_nnd
#      24 import pynndescent.distances as pynnd_dist
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/pynndescent/sparse.py:10
#       7 import numba
#       9 from pynndescent.utils import norm, tau_rand
# ---> 10 from pynndescent.distances import (
#      11     kantorovich,
#      12     jensen_shannon_divergence,
#      13     symmetric_kl_divergence,
#      14 )
#      16 FLOAT32_EPS = np.finfo(np.float32).eps
#      17 FLOAT32_MAX = np.finfo(np.float32).max
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/pynndescent/distances.py:1802
#    1797         result += popcnt_u8(intersection)
#    1799     return np.float32(result)
# -> 1802 @numba.njit(
#    1803     [
#    1804         "f4(u1[::1],u1[::1])",
#    1805         numba.types.float32(
#    1806             numba.types.Array(numba.types.uint8, 1, "C", readonly=True),
#    1807             numba.types.Array(numba.types.uint8, 1, "C", readonly=True),
#    1808         ),
#    1809     ],
#    1810     fastmath=True,
#    1811     nogil=True,
#    1812     boundscheck=False,
#    1813     locals={
#    1814         "result": numba.types.int32,
#    1815         "denom": numba.types.int32,
#    1816         "and_": numba.types.uint8,
#    1817         "or_": numba.types.uint8,
#    1818         "dim": numba.types.intp,
#    1819         "i": numba.types.uint16,
#    1820     },
#    1821 )
#    1822 def bit_jaccard(x, y):
#    1823     r"""Jaccard distance for bit-packed binary vectors.
#    1824
#    1825     Computes Jaccard distance for uint8 arrays where each byte contains
#    (...)   1832     More efficient than standard Jaccard for binary data.
#    1833     """
#    1834     result = 0
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/numba/core/decorators.py:234, in _jit.<locals>.wrapper(func)
#     232     with typeinfer.register_dispatcher(disp):
#     233         for sig in sigs:
# --> 234             disp.compile(sig)
#     235         disp.disable_compile()
#     236 return disp
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/numba/core/dispatcher.py:908, in Dispatcher.compile(self, sig)
#     906 with ev.trigger_event("numba:compile", data=ev_details):
#     907     try:
# --> 908         cres = self._compiler.compile(args, return_type)
#     909     except errors.ForceLiteralArg as e:
#     910         def folded(args, kws):
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/numba/core/dispatcher.py:80, in _FunctionCompiler.compile(self, args, return_type)
#      79 def compile(self, args, return_type):
# ---> 80     status, retval = self._compile_cached(args, return_type)
#      81     if status:
#      82         return retval
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/numba/core/dispatcher.py:94, in _FunctionCompiler._compile_cached(self, args, return_type)
#      91     pass
#      93 try:
# ---> 94     retval = self._compile_core(args, return_type)
#      95 except errors.TypingError as e:
#      96     self._failed_cache[key] = e
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/numba/core/dispatcher.py:107, in _FunctionCompiler._compile_core(self, args, return_type)
#     104 flags = self._customize_flags(flags)
#     106 impl = self._get_implementation(args, {})
# --> 107 cres = compiler.compile_extra(self.targetdescr.typing_context,
#     108                               self.targetdescr.target_context,
#     109                               impl,
#     110                               args=args, return_type=return_type,
#     111                               flags=flags, locals=self.locals,
#     112                               pipeline_class=self.pipeline_class)
#     113 # Check typing error if object mode is used
#     114 if cres.typing_error is not None and not flags.enable_pyobject:
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/numba/core/compiler.py:739, in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     715 """Compiler entry point
#     716
#     717 Parameter
#    (...)    735     compiler pipeline
#     736 """
#     737 pipeline = pipeline_class(typingctx, targetctx, library,
#     738                           args, return_type, flags, locals)
# --> 739 return pipeline.compile_extra(func)
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/numba/core/compiler.py:439, in CompilerBase.compile_extra(self, func)
#     437 self.state.lifted = ()
#     438 self.state.lifted_from = None
# --> 439 return self._compile_bytecode()
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/numba/core/compiler.py:505, in CompilerBase._compile_bytecode(self)
#     501 """
#     502 Populate and run pipeline for bytecode input
#     503 """
#     504 assert self.state.func_ir is None
# --> 505 return self._compile_core()
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/numba/core/compiler.py:473, in CompilerBase._compile_core(self)
#     471 res = None
#     472 try:
# --> 473     pm.run(self.state)
#     474     if self.state.cr is not None:
#     475         break
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/numba/core/compiler_machinery.py:356, in PassManager.run(self, state)
#     354 pass_inst = _pass_registry.get(pss).pass_inst
#     355 if isinstance(pass_inst, CompilerPass):
# --> 356     self._runPass(idx, pass_inst, state)
#     357 else:
#     358     raise BaseException("Legacy pass in use")
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/numba/core/compiler_lock.py:35, in _CompilerLock.__call__.<locals>._acquire_compile_lock(*args, **kwargs)
#      32 @functools.wraps(func)
#      33 def _acquire_compile_lock(*args, **kwargs):
#      34     with self:
# ---> 35         return func(*args, **kwargs)
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/numba/core/compiler_machinery.py:311, in PassManager._runPass(self, index, pss, internal_state)
#     309     mutated |= check(pss.run_initialization, internal_state)
#     310 with SimpleTimer() as pass_time:
# --> 311     mutated |= check(pss.run_pass, internal_state)
#     312 with SimpleTimer() as finalize_time:
#     313     mutated |= check(pss.run_finalizer, internal_state)
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/numba/core/compiler_machinery.py:272, in PassManager._runPass.<locals>.check(func, compiler_state)
#     271 def check(func, compiler_state):
# --> 272     mangled = func(compiler_state)
#     273     if mangled not in (True, False):
#     274         msg = ("CompilerPass implementations should return True/False. "
#     275                "CompilerPass with name '%s' did not.")
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/numba/core/typed_passes.py:114, in BaseTypeInference.run_pass(self, state)
#     108 """
#     109 Type inference and legalization
#     110 """
#     111 with fallback_context(state, 'Function "%s" failed type inference'
#     112                       % (state.func_id.func_name,)):
#     113     # Type inference
# --> 114     typemap, return_type, calltypes, errs = type_inference_stage(
#     115         state.typingctx,
#     116         state.targetctx,
#     117         state.func_ir,
#     118         state.args,
#     119         state.return_type,
#     120         state.locals,
#     121         raise_errors=self._raise_errors)
#     122     state.typemap = typemap
#     123     # save errors in case of partial typing
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/numba/core/typed_passes.py:95, in type_inference_stage(typingctx, targetctx, interp, args, return_type, locals, raise_errors)
#      93     infer.build_constraint()
#      94     # return errors in case of partial typing
# ---> 95     errs = infer.propagate(raise_errors=raise_errors)
#      96     typemap, restype, calltypes = infer.unify(raise_errors=raise_errors)
#      98 return _TypingResults(typemap, restype, calltypes, errs)
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/numba/core/typeinfer.py:1075, in TypeInferer.propagate(self, raise_errors)
#    1072 oldtoken = newtoken
#    1073 # Errors can appear when the type set is incomplete; only
#    1074 # raise them when there is no progress anymore.
# -> 1075 errors = self.constraints.propagate(self)
#    1076 newtoken = self.get_state_token()
#    1077 self.debug.propagate_finished()
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/numba/core/typeinfer.py:160, in ConstraintNetwork.propagate(self, typeinfer)
#     157 with typeinfer.warnings.catch_warnings(filename=loc.filename,
#     158                                        lineno=loc.line):
#     159     try:
# --> 160         constraint(typeinfer)
#     161     except ForceLiteralArg as e:
#     162         errors.append(e)
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/numba/core/typeinfer.py:572, in CallConstraint.__call__(self, typeinfer)
#     569     fnty = typevars[self.func].getone()
#     570 with new_error_context("resolving callee type: {fnty}",
#     571                        fnty=fnty):
# --> 572     self.resolve(typeinfer, typevars, fnty)
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/numba/core/typeinfer.py:595, in CallConstraint.resolve(self, typeinfer, typevars, fnty)
#     593     fnty = fnty.instance_type
#     594 try:
# --> 595     sig = typeinfer.resolve_call(fnty, pos_args, kw_args)
#     596 except ForceLiteralArg as e:
#     597     # Adjust for bound methods
#     598     folding_args = ((fnty.this,) + tuple(self.args)
#     599                     if isinstance(fnty, types.BoundFunction)
#     600                     else self.args)
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/numba/core/typeinfer.py:1569, in TypeInferer.resolve_call(self, fnty, pos_args, kw_args)
#    1566     return sig
#    1567 else:
#    1568     # Normal non-recursive call
# -> 1569     return self.context.resolve_function_type(fnty, pos_args, kw_args)
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/numba/core/typing/context.py:279, in BaseContext.resolve_function_type(self, func, args, kws)
#     277 # Prefer user definition first
#     278 try:
# --> 279     res = self._resolve_user_function_type(func, args, kws)
#     280 except errors.TypingError as e:
#     281     # Capture any typing error
#     282     last_exception = e
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/numba/core/typing/context.py:335, in BaseContext._resolve_user_function_type(self, func, args, kws, literals)
#     331         return self.resolve_function_type(func_type, args, kws)
#     333 if isinstance(func, types.Callable):
#     334     # XXX fold this into the __call__ attribute logic?
# --> 335     return func.get_call_type(self, args, kws)
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/numba/core/types/functions.py:311, in BaseFunction.get_call_type(self, context, args, kws)
#     308         nolitargs = tuple([_unlit_non_poison(a) for a in args])
#     309         nolitkws = {k: _unlit_non_poison(v)
#     310                     for k, v in kws.items()}
# --> 311         sig = temp.apply(nolitargs, nolitkws)
#     312 except Exception as e:
#     313     if not isinstance(e, errors.NumbaError):
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/numba/core/typing/templates.py:358, in AbstractTemplate.apply(self, args, kws)
#     356 def apply(self, args, kws):
#     357     generic = getattr(self, "generic")
# --> 358     sig = generic(args, kws)
#     359     # Enforce that *generic()* must return None or Signature
#     360     if sig is not None:
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/numba/core/typing/templates.py:966, in _IntrinsicTemplate.generic(self, args, kws)
#     962 def generic(self, args, kws):
#     963     """
#     964     Type the intrinsic by the arguments.
#     965     """
# --> 966     lower_builtin = self._get_target_registry('intrinsic').lower
#     967     cache_key = self.context, args, tuple(kws.items())
#     968     try:
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/numba/core/typing/templates.py:947, in _TemplateTargetHelperMixin._get_target_registry(self, reason)
#     924 tgtctx = disp.targetdescr.target_context
#     925 # This is all workarounds...
#     926 # The issue is that whilst targets shouldn't care about which registry
#     927 # in which to register lowering implementations, the CUDA target
#    (...)    945 # In case the target has swapped, e.g. cuda borrowing cpu, refresh to
#     946 # populate.
# --> 947 tgtctx.refresh()
#     948 if builtin_registry in tgtctx._registries:
#     949     reg = builtin_registry
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/numba/core/base.py:277, in BaseContext.refresh(self)
#     273 self.install_registry(builtin_registry)
#     275 # Also refresh typing context, since @overload declarations can
#     276 # affect it.
# --> 277 self.typing_context.refresh()
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/numba/core/typing/context.py:237, in BaseContext.refresh(self)
#     232 def refresh(self):
#     233     """
#     234     Refresh context with new declarations from known registries.
#     235     Useful for third-party extensions.
#     236     """
# --> 237     self.load_additional_registries()
#     238     # Some extensions may have augmented the builtin registry
#     239     self._load_builtins()
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/numba/core/typing/context.py:825, in Context.load_additional_registries(self)
#     823 self.install_registry(cmathdecl.registry)
#     824 self.install_registry(enumdecl.registry)
# --> 825 self.install_registry(listdecl.registry)
#     826 self.install_registry(mathdecl.registry)
#     827 self.install_registry(npydecl.registry)
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/numba/core/typing/context.py:508, in BaseContext.install_registry(self, registry)
#     504     self._registries[registry] = loader
#     506 from numba.core.target_extension import (get_local_target,
#     507                                          resolve_target_str)
# --> 508 current_target = get_local_target(self)
#     510 def is_for_this_target(ftcls):
#     511     metadata = getattr(ftcls, 'metadata', None)
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/numba/core/target_extension.py:60, in get_local_target(context)
#      58 # TODO: Should this logic be reversed to prefer TLS override?
#      59 if len(context.callstack._stack) > 0:
# ---> 60     target = context.callstack[0].target
#      61 else:
#      62     target = target_registry.get(current_target(), None)
#
# File ~/Desktop/text_analysis/OptionsNewsIndicator/.venv/lib/python3.12/site-packages/numba/core/typing/context.py:54, in CallStack.__getitem__(self, index)
#      51     # fail_cache only last for the current compilation session
#      52     self._fail_cache = {}
# ---> 54 def __getitem__(self, index):
#      55     """
#      56     Returns item in the stack where index=0 is the top and index=1 is
#      57     the second item from the top.
#      58     """
#      59     return self._stack[len(self) - index - 1]
#
# KeyboardInterrupt:

# %%
df_index[['cluster_id', 'un_date']].head(50)

# %%
import plotly.express as px
import pandas as pd
from datetime import timedelta

# 1. Считаем UMAP (как и раньше)
# Рекомендую увеличить n_neighbors для более "глобальной" структуры


# 2. Кластеризация через HDBSCAN
# min_cluster_size — минимальное кол-во новостей, чтобы они считались темой
clusterer = hdbscan.HDBSCAN(
    min_cluster_size=5, 
    metric='euclidean', 
    cluster_selection_method='eom'
)
cluster_labels = clusterer.fit_predict(embedding)

# 3. Собираем данные в DataFrame

df_index['cluster'] = cluster_labels.astype(str)

# %%
df_index['cluster_id'] = cluster_labels

def get_min_date(group):
    return min(group['scraped_date'])

# df_index['min_time'] = df_index.groupby(['un_date']).transform(lambda x: print(x))
# df_index['min_time'] = df_index.groupby(['un_date']).transform(lambda x: x['scraped_date'].min())
df_index['min_time'] = df_index.groupby('un_date')['scraped_date'].transform('min')
df_index['min_time'] = pd.to_datetime(df_index['min_time'])
print(df_index.groupby('un_date')['min_time'])

# %% [markdown]
# ### Отрисовка кластеризации

# %%
import textwrap

# Функция для красивого разбиения текста
def format_hover_text(text, width=70):
    if not text:
        return ""
    # Разбиваем текст на строки по ширине (например, 70 символов)
    wrapped = textwrap.fill(str(text), width=width)
    # Заменяем обычный перенос строки на HTML-тег <br>
    return wrapped.replace('\n', '<br>')

# Применяем форматирование
df_index['formatted_summary'] = df_index['summary'].apply(lambda x: format_hover_text(x, width=80))

df_index['hoover_date'] = df_index['scraped_date'].strftime('%Y-%m-%d %H:%M:%S')

# 1. Приводим к строке, чтобы Plotly воспринимал кластеры как категории
df_index['cluster'] = df_index['cluster'].astype(str)

fig = px.scatter_3d(
    df_index, 
    x='x', y='y', z='z',
    color='cluster',
    color_discrete_map={'-1': '#d3d3d3'},
    hover_data={'formatted_summary': True, 'x': False, 'y': False, 'z': False, 'cluster': True, 'hoover_date': True},
    title='Автоматическая кластеризация новостей (HDBSCAN)',
    template='plotly_white',
    width=2700, height=1000
)

# Важная настройка: заставляем подсказку не ограничивать ширину и выравниваем текст
fig.update_layout(
    hoverlabel=dict(
        bgcolor="white",
        font_size=12,
        align="left" # Текст будет прижат к левому краю внутри окна
    )
)

fig.update_traces(marker=dict(size=5, opacity=0.7))
fig.show(renderer="browser")  # сразу откроет в браузере на весь экран

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import textwrap

def format_hover_text(text, width=70):
    if not text:
        return ""
    wrapped = textwrap.fill(str(text), width=width)
    return wrapped.replace('\n', '<br>')

df_index['hoover_date'] = pd.to_datetime(df_index['scraped_date'].values).strftime('%Y-%m-%d %H:%M:%S')
df_index['formatted_summary'] = df_index['summary'].apply(lambda x: format_hover_text(x, width=80))

# Создаем фигуру с слайдером
fig = go.Figure()

# Получаем уникальные даты
unique_dates = sorted(df_index['un_date'].unique())

# Добавляем след для каждой даты
for date in unique_dates:
    group = df_index[df_index['un_date'] == date]
    customdata = group[['formatted_summary', 'hoover_date', 'title']].values
    
    fig.add_trace(
        go.Scatter3d(
            x=group['x'],
            y=group['y'],
            z=group['z'],
            mode='markers',
            marker=dict(
                size=5,
                color=group['cluster_id'],
                colorscale='Viridis',
                showscale=True,
                colorbar=dict(title="Cluster ID"),
                opacity=0.8
            ),
            text=group['title'],
            customdata=customdata,
            hovertemplate='<b>%{text}</b><br><br>' +
                         'Summary: %{customdata[0]}<br>' +
                         'Date: %{customdata[1]}<br>' +
                         'Cluster: %{marker.color}<br>' +
                         '<extra></extra>',
            name=f'{date}',
            visible=(date == unique_dates[0])  # Показываем только первую дату
        )
    )

# Создаем шаги для слайдера
steps = []
for i, date in enumerate(unique_dates):
    step = dict(
        method="update",
        args=[{"visible": [False] * len(unique_dates)},
              {"title": f"Date: {date}"}],
        label=str(date)
    )
    step["args"][0]["visible"][i] = True
    steps.append(step)

# Создаем слайдер
sliders = [dict(
    active=0,
    currentvalue={"prefix": "Date: "},
    pad={"t": 50},
    steps=steps
)]

# Обновляем layout
fig.update_layout(
    sliders=sliders,
    height=800,
    width=1200,
    title=f"Date: {unique_dates[0]}",
    hoverlabel=dict(
        bgcolor="white",
        font_size=12,
        font_family="Arial",
        align="left"
    )
)

fig.show(renderer="browser")

# %% [markdown]
# ### График изменения цены сбера против кластеров новостей

# %%
from moexalgo import Ticker, session
from datetime import timedelta
username = "382hejw@gmail.com"
password = "nTpM7b#N*wipF56"
session.authorize(username, password)

# %%
sber = Ticker('SBER')

start_date = df_index.index.min().date()
end_date = df_index.index.max().date()

sber_candles = sber.candles(start=start_date, end=end_date, period='15min')
sber_candles['end'] = pd.to_datetime(sber_candles['end'])
sber_candles.set_index('end', inplace=True)

sber_candles['candle_change'] = sber_candles['close'] - sber_candles['open']
sber_candles['mean'] = sber_candles['candle_change'].rolling(window='1D').mean()
sber_candles['std'] = sber_candles['candle_change'].rolling(window='1D').std()
sber_candles['z-score'] = (sber_candles['candle_change'] - sber_candles['mean']) / sber_candles['std']

# %%
print(df_index)

# %%
import pandas as pd
import plotly.express as px

# 1. Подготовка данных к объединению
# Убеждаемся, что время в обоих DF имеет правильный формат и отсортировано
df_index['min_time'] = pd.to_datetime(df_index['min_time']).dt.tz_localize(None)
sber_candles = sber_candles.sort_values('end')
df_index = df_index.sort_values('min_time')

# 2. Объединение: ищем ближайшую свечу Сбера "впереди" (direction='forward')
# Это сопоставит min_time (13:07) со свечой 13:15
merged_df = pd.merge_asof(
    df_index, 
    sber_candles['z-score'], 
    left_on='min_time', 
    right_on=sber_candles.index, 
    direction='forward'
)

# 3. Убираем шум (аутлайнеры -1), если они не нужны для анализа корреляции
plot_data = merged_df[merged_df['cluster_id'] != '-1'].copy()
plot_data['cluster_id'] = plot_data['cluster_id'].astype(str)

# 4. Построение графика
fig = px.scatter(
    plot_data,
    x='cluster_id',
    y='z-score',
    color='z-score',
    color_continuous_scale='RdBu_r', # Красный для высокого Z, синий для низкого
    hover_data=['min_time', 'summary'],
    title='Влияние кластеров новостей на Z-score SBER',
    labels={'z-score': 'Z-score (15 min)', 'cluster_id': 'ID Кластера'}
)

# Добавим горизонтальные линии для наглядности аномалий
fig.add_hline(y=2, line_dash="dash", line_color="red", annotation_text="Strong Buy/Sell signal")
fig.add_hline(y=-2, line_dash="dash", line_color="red")

fig.show(renderer="browser")

# %%
print(plot_data.index)

# %% [markdown]
# ## Подсчет Z-score индикатора

# %%
df_index.index = pd.to_datetime(df_index.index, format='mixed', utc=True)
df_index = df_index.sort_index()
df_index['mean'] = df_index['news_index'].rolling(window='1D').mean()
df_index['std'] = df_index['news_index'].rolling(window='1D').std()
df_index['z'] = (df_index['news_index'] - df_index['mean']) / df_index['std']

# %% [markdown]
# ## Визуализация - SBER IV, цена SBER vs INDEX (Z-score)

# %%
grp_index = df_index.groupby(pd.Grouper(freq='12h')).agg({'news_index': 'mean'})
sber = Ticker('SBER')

start_date = df_index.index.min().date()
end_date = df_index.index.max().date()

sber_candles = sber.candles(start=start_date, end=end_date, period='1h')
sber_candles['end'] = pd.to_datetime(sber_candles['end'])
options_df = pd.read_csv('sber_options_with_iv.csv')
options_df['date'] = pd.to_datetime(options_df['date'])

# %%
import plotly.graph_objects as go
import pandas as pd
import numpy as np
from plotly.subplots import make_subplots

# Строим график с двумя subplot'ами
fig = make_subplots(
    rows=2, cols=1,
    shared_xaxes=True,
    vertical_spacing=0.1,
    subplot_titles=('Курс акций Сбера', 'Новостной индикатор (Z-score)')
)

# Добавляем курс Сбера (без масштабирования, просто логарифм)
fig.add_trace(
    go.Scatter(
        x=sber_candles['end'], 
        y=sber_candles['close'], 
        mode='lines', 
        name='Цена акций Сбера',
        line=dict(color='blue', width=2),
        hovertemplate='Дата: %{x}<br>log(Цена): %{y:.3f}<extra>Цена акций</extra>'
    ),
    row=1, col=1
)

# Добавляем Z-score индикатор (без масштабирования, оригинальные значения)
fig.add_trace(
    go.Scatter(
        x=df_index.index, 
        y=df_index['news_index'], 
        mode='lines', 
        name='Новостной индикатор',
        line=dict(color='purple', width=2),
        hovertemplate='Дата: %{x}<br>Z-score: %{y:.3f}<extra></extra>'
    ),
    row=2, col=1
)

# Добавляем нулевую линию для Z-score (опционально)
fig.add_hline(
    y=0, 
    line_dash="dash", 
    line_color="gray", 
    opacity=0.5,
    row=2, col=1
)

# Улучшенный layout
fig.update_layout(
    title={
        'text': 'Сравнение курса Сбера и новостного индикатора',
        'x': 0.5,
        'xanchor': 'center',
        'font': dict(size=20)
    },
    hovermode='x unified',
    legend=dict(
        yanchor="top",
        y=0.99,
        xanchor="left",
        x=0.01,
        bgcolor='rgba(255, 255, 255, 0.8)'
    ),
    template='plotly_white',
    width=1200,
    height=700  # немного увеличил высоту для двух графиков
)

# Настройка осей
fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=1, label="1m", step="month", stepmode="backward"),
            dict(count=3, label="3m", step="month", stepmode="backward"),
            dict(count=6, label="6m", step="month", stepmode="backward"),
            dict(count=1, label="YTD", step="year", stepmode="todate"),
            dict(count=1, label="1y", step="year", stepmode="backward"),
            dict(step="all")
        ])
    ),
    row=2, col=1  # настройки для нижнего графика
)

# Настройка сетки для обоих графиков
fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='lightgray', row=1, col=1)
fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='lightgray', row=2, col=1)
fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='lightgray', row=2, col=1)

# Добавляем подписи осей
fig.update_yaxes(title_text="Цена", row=1, col=1)
fig.update_yaxes(title_text="Z-score", row=2, col=1)
fig.update_xaxes(title_text="Дата", row=2, col=1)

fig.show()

# %%
sber_candles['end']
print(df_index.index, type(df_index.index), sber_candles['end'].head(5), type(sber_candles['end']))
ardl_df = pd.merge(df_index, sber_candles, left_on=df_index.index, right_on=sber_candles['end'])

# %%
for row in df_index.itertuples():
    print((df_index.vector))

# %%
import faiss
import numpy as np

dimension = 1024
threshold = 0.92

for idx, groups in df_index.groupby('un_date'):
    day_embeddings = np.stack(group['vector'].values).astype('float32')
    index = faiss.IndexFlatIP(dimension)
    index.add(day_embeddings)
    # upper_boundary, down_boundary = groups.index[0], groups.index[-1]
    print(f'{'='*30}ПОИСК ПО {idx} ДНЮ')
    # print(upper_boundary, down_boundary)
    lims, dists, inds = index.range_search(day_embeddings, threshold)
    for row in groups.itertuples():
        # print(groups)
        summary_embedding = np.array([row.vector])
        
        lims, dists, inds = index.range_search(summary_embedding[down_boundary:upper_boundary+1], threshold)
        if len(inds) > 1:
            print(f'Для новости\n"{row.summary[:100]}..."\nнайдены соседи (первые 3)')
            for idx in inds[1:]:
                print(f'[{df_index.iloc[idx]['scraped_date']}] - {df_index.iloc[idx]['summary'][:100]}...\n')
        else:
            print(f'Не найдено новостей, похожих на:\n{df_index.iloc[inds[0]]['summary'][:100]}\n')

# %%
import faiss
import numpy as np

dimension = 1024
threshold = 0.95
df_index['news_order'] = -1

# 1. Цикл по дням
for date_idx, group in df_index.groupby('un_date'):
    print(f"\n{'='*30}")
    print(f"Обработка дня: {date_idx}")
    
    # Готовим матрицу эмбеддингов только для ЭТОГО дня
    # Предполагаем, что в колонке 'vector' лежат списки или массивы
    day_embeddings = np.stack(group['vector'].values).astype('float32')
    
    # Создаем индекс специально для этого дня
    index = faiss.IndexFlatIP(dimension)
    index.add(day_embeddings)
    
    # 2. Ищем похожие новости внутри этого дня
    # Можно искать сразу для всей группы (это быстрее, чем циклом)
    lims, dists, inds = index.range_search(day_embeddings, threshold)
    
    # 3. Разбираем результаты
    for i in range(len(group)):
        # Получаем индексы соседей для i-й новости текущего дня
        start, end = lims[i], lims[i+1]
        neighbor_indices_in_day = inds[start:end]
        neighbor_dists = dists[start:end]
        
        # Исключаем саму себя (где индекс равен i)
        others_mask = neighbor_indices_in_day != i
        actual_neighbors = neighbor_indices_in_day[others_mask]
        
        if len(actual_neighbors) > 0:
            current_news = group.iloc[i]
            print(f"\nНовость: {current_news['summary'][:80]}...")
            print(f"Найдено дублей в этот день: {len(actual_neighbors)}")
            
            for neighbor_idx in actual_neighbors:
                neighbor_news = group.iloc[neighbor_idx]
                print(f"  -> [{neighbor_news['scraped_date']}] {neighbor_news['summary'][:60]}...")

# %%
import faiss
import numpy as np

# Сортировка по времени - фундамент для news_order
df_index = df_index.sort_values('scraped_date').reset_index(drop=True)

# Инициализируем колонки
df_index['news_order'] = 1
df_index['similar_news_count'] = 0  # Сколько всего похожих нашли за день

dimension = 1024
threshold = 0.93

for date_val, group in df_index.groupby('un_date'):
    if len(group) < 2:
        continue
    
    # Подготовка векторов дня
    day_vectors = np.stack(group['vector'].values).astype('float32')
    faiss.normalize_L2(day_vectors)
    
    index = faiss.IndexFlatIP(dimension)
    index.add(day_vectors)
    
    # Поиск всех похожих
    lims, dists, inds = index.range_search(day_vectors, threshold)
    
    group_orders = []
    group_similar_counts = []
    
    for i in range(len(group)):
        # Получаем индексы всех соседей (включая саму новость)
        neighbor_indices = inds[lims[i]:lims[i+1]]
        
        # 1. Порядковый номер (сколько вышло РАНЬШЕ нас)
        earlier_count = np.sum(neighbor_indices < i)
        group_orders.append(earlier_count + 1)
        
        # 2. Общее кол-во похожих за день (минус сама новость)
        total_similar = len(neighbor_indices) - 1
        group_similar_counts.append(total_similar)
    
    # Массовое присваивание для всей группы (быстрый способ)
    df_index.loc[group.index, 'news_order'] = group_orders
    df_index.loc[group.index, 'similar_news_count'] = group_similar_counts

print("Расчет завершен успешно.")
# Out:
# Расчет завершен успешно.

# %%
df_index[df_index['similar_news_count'] > 0]\
        .sort_values('similar_news_count', ascending=False)\
        [['scraped_date', 'news_order', 'similar_news_count', 'summary']]
# Out:
#                   scraped_date  news_order  similar_news_count  \
# 370  2025-12-26 12:20:00+00:00          11                  15
# 346  2025-12-26 08:15:00+00:00           2                  14
# 347  2025-12-26 08:32:00+00:00           3                  14
# 369  2025-12-26 12:18:00+00:00          10                  13
# 349  2025-12-26 09:25:00+00:00           4                  12
# ...                        ...         ...                 ...
# 520  2026-01-10 21:48:00+00:00           2                   1
# 521  2026-01-10 22:16:00+00:00           1                   1
# 522  2026-01-10 22:43:00+00:00           2                   1
# 528  2026-01-12 05:30:00+00:00           1                   1
# 1092 2026-02-26 20:27:00+00:00           2                   1
#
#                                                 summary
# 370   С 1 января 2026 года Сбербанк изменит условия ...
# 346   Сбербанк введет комиссию за неиспользуемые пла...
# 347   🔥 С 1 января 2026 Сбер сделает платным обслужи...
# 369   «Сбер» также на своем сайте перечислил условия...
# 349   "С 1 января обслуживание вашего платежного сче...
# ...                                                 ...
# 520   Сбербанк сообщил о новой схеме мошенничества с...
# 521   Сбербанк вернёт деньги за советские вклады: ст...
# 522   Программа компенсации по вкладам, сделанным в ...
# 528   На Android приложение скачивают с сайта Сбера ...
# 1092  СБЕРБАНК [новости] НОВОСТИ АКЦИЙ РОССИИ Сберба...
#
# [389 rows x 4 columns]
